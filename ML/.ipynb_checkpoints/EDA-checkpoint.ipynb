# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import optuna
sns.set_style('darkgrid')

# %%
train = pd.read_csv('final_train.csv')
test = pd.read_csv('final_test.csv')

# %%
#Dropping the unnecessary columns
train = train.drop(['oem','variant', 'model', 'Height', 'Wheel Base'], axis = 1)#height is incorrectly labelled or recorded
test = test.drop(['oem', 'variant', 'model', 'Height', 'Wheel Base'], axis = 1)

# %%
#Creating X_train and y_train
X_train = train.drop('listed_price', axis = 1)
y_train = train['listed_price']
X_test = test.drop('listed_price', axis = 1)
y_test = test['listed_price']
y_test
# Out:
# 0        950000.0
# 1        500000.0
# 2        738000.0
# 3        660000.0
# 4        899999.0
#           ...
# 3770     295000.0
# 3771     735859.0
# 3772     245000.0
# 3773    1249999.0
# 3774     200000.0
# Name: listed_price, Length: 3775, dtype: float64

# %%
corr_mat = train.corr()

# %% [markdown]
# ## Pearson's Correlation

# %%
plt.figure(figsize = (20, 20))
sns.heatmap(data = corr_mat, annot = True)
plt.show()

# %% [markdown]
# **REPORT**:
# - The correlation map is definitely giving a lot of crucial information
# - *Front Tread* and *Rear Tread* have very high corr -> (0.94)
# - *Max Torque At* and *Max Power At* have very high corr -> (0.88)
# - *Acceleration* and *Top Speed* are highly negatively correlated -> (-0.79)
# - *Wheel Base*, *Length* and *Width*  are also highly correlated
# - *Valves per Cylinder* is also a column with very high correlation with multiple columns
# - All the *car_features* columns are highly correlated too

# %% [markdown]
# **Feature Engineering Ideas**:
# - avg_measure = $\frac{length + width}{3}$
# - Features = $top + comfort + interior + exterior + safety$
# - Total Valves = No. of Cylinders $\times$ Valves per Cylinder
# - Tread = $\frac{Front Tread + Rear Tread}{2}$

# %%
cat_cols = [col for col in train.columns
           if train[col].dtype == 'O']
cat_un = [train[col].nunique() for col in cat_cols]
cat_info = pd.DataFrame({'column' : cat_cols, 'unique values' : cat_un})
cat_info
# Out:
#                  column  unique values
# 0          transmission              2
# 1                  fuel              5
# 2   Valve Configuration              5
# 3            Drive Type              4
# 4            owner_type              6
# 5    Fuel Supply System             10
# 6                  body             11
# 7              Gear Box             11
# 8         Steering Type              2
# 9      Front Brake Type              5
# 10      Rear Brake Type              5
# 11            Tyre Type              4
# 12       exterior_color             12

# %%
num_cols = [col for col in train.columns
           if col not in cat_cols]
num_un = [train[col].nunique() for col in num_cols]
num_info = pd.DataFrame({'column' : num_cols, 'unique values' : num_un})
num_info
# Out:
#                   column  unique values
# 0                  myear             33
# 1                     km          21733
# 2           top_features             10
# 3       comfort_features             39
# 4      interior_features             20
# 5      exterior_features             28
# 6        safety_features             50
# 7         No of Cylinder            397
# 8    Valves per Cylinder            260
# 9          Turbo Charger              2
# 10         Super Charger              2
# 11                Length            284
# 12                 Width            209
# 13           Front Tread            170
# 14            Rear Tread            189
# 15           Kerb Weight            532
# 16                 Seats             10
# 17             Top Speed            188
# 18          Acceleration            242
# 19                 Doors              2
# 20          Cargo Volume            204
# 21   Max Power Delivered             10
# 22          Max Power At             55
# 23  Max Torque Delivered              5
# 24         Max Torque At            114
# 25          listed_price           6319

# %%
heh = [col for col in num_cols if train[col].nunique() > 50]

# %%
#Plotting categorical features distribution
i = 1
plt.figure(figsize = (15, 100))
for col in cat_cols:
    plt.subplot(10, 2, i)
    sns.histplot(data = train[col])
    plt.title(col)
    i+= 1
plt.tight_layout()

# %%
#plotting distribution of numerical features
j = 1
plt.figure(figsize = (15, 100))
for col in num_cols:
    plt.subplot(15, 2, j)
    sns.kdeplot(data = train[col], fill = True)
    plt.title(col)
    j += 1
plt.tight_layout()

# %% [markdown]
# ## Outliers

# %%
#number summaries for data
desc = train.describe().T
desc
# Out:
#                         count           mean           std      min  \
# myear                 33776.0    2015.578636  3.774640e+00   1983.0
# km                    33776.0   62224.967314  5.498804e+04    101.0
# top_features          33776.0       8.817383  4.835136e-01      1.0
# comfort_features      33776.0      15.090182  6.072644e+00      1.0
# interior_features     33776.0      10.070956  2.345593e+00      1.0
# exterior_features     33776.0      10.060648  4.576099e+00      1.0
# safety_features       33776.0      21.709257  6.926763e+00      1.0
# No of Cylinder        33776.0    4112.195622  3.965827e+02   3099.0
# Valves per Cylinder   33776.0    1725.051012  1.270810e+02   1410.0
# Length                33776.0    1577.408362  1.143670e+02   1281.0
# Width                 33776.0    2545.219950  1.535570e+02   1840.0
# Front Tread           33776.0    1472.493827  7.372552e+01   1205.0
# Rear Tread            33776.0    1469.917968  8.123867e+01     15.0
# Kerb Weight           33776.0    1179.619149  2.990148e+02    600.0
# Seats                 33776.0       3.817207  5.295541e-01      1.0
# Top Speed             33776.0     172.132739  2.230096e+01     80.0
# Acceleration          33776.0      13.134293  2.746565e+00      4.1
# Doors                 33776.0       3.920239  3.913621e-01      2.0
# Cargo Volume          33776.0     355.218984  1.246635e+02     29.0
# Max Power Delivered   33776.0       5.235167  7.157128e-01      0.0
# Max Power At          33776.0    5106.307386  1.029032e+03   1620.0
# Max Torque Delivered  33776.0       4.664318  4.951291e-01      2.0
# Max Torque At         33776.0    3164.192418  9.970674e+02    160.0
# listed_price          33776.0  788568.486144  3.130544e+06  11963.0
#
#                                 25%            50%            75%  \
# myear                   2013.000000    2016.000000    2018.000000
# km                     31755.500000   56520.500000   83028.250000
# top_features               9.000000       9.000000       9.000000
# comfort_features          10.000000      15.000000      19.000000
# interior_features          9.000000      10.000000      12.000000
# exterior_features          6.000000      10.000000      13.000000
# safety_features           17.000000      22.000000      27.000000
# No of Cylinder          3795.000000    3995.000000    4440.000000
# Valves per Cylinder     1680.000000    1715.000000    1790.000000
# Length                  1495.000000    1530.000000    1640.000000
# Width                   2425.000000    2520.000000    2636.000000
# Front Tread             1455.367356    1484.868545    1515.000000
# Rear Tread              1454.000000    1480.000000    1520.000000
# Kerb Weight              942.867696    1103.000000    1491.285879
# Seats                      4.000000       4.000000       4.000000
# Top Speed                157.471212     170.000000     185.000000
# Acceleration              11.546351      12.900000      14.604886
# Doors                      4.000000       4.000000       4.000000
# Cargo Volume             255.150511     346.000000     460.000000
# Max Power Delivered        5.000000       5.000000       5.000000
# Max Power At            4000.000000    5500.000000    6000.000000
# Max Torque Delivered       4.000000       5.000000       5.000000
# Max Torque At           2125.000000    3300.000000    4000.000000
# listed_price          320000.000000  525000.000000  853769.000000
#
#                                max
# myear                 2.023000e+03
# km                    6.300000e+06
# top_features          9.000000e+00
# comfort_features      3.900000e+01
# interior_features     1.900000e+01
# exterior_features     2.700000e+01
# safety_features       4.900000e+01
# No of Cylinder        5.469000e+03
# Valves per Cylinder   2.220000e+03
# Length                2.075000e+03
# Width                 3.396000e+03
# Front Tread           1.705000e+03
# Rear Tread            1.834000e+03
# Kerb Weight           2.962000e+03
# Seats                 1.600000e+01
# Top Speed             2.850000e+02
# Acceleration          4.404000e+01
# Doors                 4.000000e+00
# Cargo Volume          2.055000e+03
# Max Power Delivered   1.300000e+01
# Max Power At          7.000000e+03
# Max Torque Delivered  6.000000e+00
# Max Torque At         2.180000e+04
# listed_price          5.500006e+08

# %%
train_outliers = {}
test_outliers = {}

# %%
def outliers(col):
    var_name = f"{col}_outliers"
    train_outliers[var_name] = []
    test_outliers[var_name] = []
    iqr = desc.loc[col, '75%'] - desc.loc[col, '25%']
    h_brac = desc.loc[col, '75%'] + 1.5 * iqr
    l_brac = desc.loc[col, '25%'] - 1.5 * iqr
    trouts = train.loc[(train[col] < l_brac) | (train[col] > h_brac)]
    teouts = test.loc[(test[col] < l_brac) | (test[col] > h_brac)]
    train_outliers[var_name] = list(trouts.index)
    test_outliers[var_name] = list(teouts.index)

# %%
for col in heh:
    outliers(col)

# %%
print("For the train dataset:")
for col in heh:
    var = f"{col}_outliers"
    print(f"The no. of outliers in {col}:", len(train.iloc[train_outliers[var]]))
# Out:
# For the train dataset:
# The no. of outliers in km: 766
# The no. of outliers in No of Cylinder: 4
# The no. of outliers in Valves per Cylinder: 3996
# The no. of outliers in Length: 724
# The no. of outliers in Width: 583
# The no. of outliers in Front Tread: 3757
# The no. of outliers in Rear Tread: 4067
# The no. of outliers in Kerb Weight: 130
# The no. of outliers in Top Speed: 1202
# The no. of outliers in Acceleration: 700
# The no. of outliers in Cargo Volume: 70
# The no. of outliers in Max Power At: 0
# The no. of outliers in Max Torque At: 1
# The no. of outliers in listed_price: 2841

# %%
print("For the test dataset:")
for col in heh:
    var = f"{col}_outliers"
    print(f"The no. of outliers in {col}:", len(test.iloc[test_outliers[var]]))
# Out:
# For the test dataset:
# The no. of outliers in km: 98
# The no. of outliers in No of Cylinder: 0
# The no. of outliers in Valves per Cylinder: 449
# The no. of outliers in Length: 79
# The no. of outliers in Width: 66
# The no. of outliers in Front Tread: 427
# The no. of outliers in Rear Tread: 474
# The no. of outliers in Kerb Weight: 16
# The no. of outliers in Top Speed: 149
# The no. of outliers in Acceleration: 92
# The no. of outliers in Cargo Volume: 13
# The no. of outliers in Max Power At: 0
# The no. of outliers in Max Torque At: 1
# The no. of outliers in listed_price: 345

# %% [markdown]
# -**REPORT:**
# - The outliers are not really outliers in most cases, they exist in the real world and are not a consequence of illegitimate data entries
# -There were outliers on the basis of the car makers which have been removed at the beginning
# (Car makers having less than 6 listings in the dataset)

# %% [markdown]
# # Pipelines

# %%
from dirty_cat import SuperVectorizer, TableVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.preprocessing import RobustScaler

# %%
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression,Lasso, Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor, ExtraTreesRegressor

# %%
#Scaler
rs = RobustScaler()

# %%
#Encoder objects
tv = TableVectorizer()
sv = SuperVectorizer()
# Out:
# C:\Users\rajni\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:67: FutureWarning: Class SuperVectorizer is deprecated; use TableVectorizer instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
#Table Vectorizer dataset
tv_X_train = tv.fit_transform(X_train, y_train)
tv_X_test = tv.transform(X_test)

# %%
#SuperVectorizer dataset
sv_X_train = sv.fit_transform(X_train, y_train)
sv_X_test = sv.transform(X_test)

# %% [markdown]
# ## 1.Laborious pipeline

# %%
#Creating the new train and test
lX_train = train.drop('listed_price', axis = 1)
ly_train = train['listed_price']
testX = test.drop('listed_price', axis = 1)
testy = test['listed_price']
lX_test, lX_valid, ly_test, ly_valid = train_test_split(testX, testy, train_size = 0.5)

# %%
catcols = [col for col in lX_train if lX_train[col].dtype == 'O']
catvals = [lX_train[col].nunique() for col in catcols]
katie = pd.DataFrame({'catcols': catcols, 'Uniques' : catvals})
katie
# Out:
#                 catcols  Uniques
# 0          transmission        2
# 1                  fuel        5
# 2   Valve Configuration        5
# 3            Drive Type        4
# 4            owner_type        6
# 5    Fuel Supply System       10
# 6                  body       11
# 7              Gear Box       11
# 8         Steering Type        2
# 9      Front Brake Type        5
# 10      Rear Brake Type        5
# 11            Tyre Type        4
# 12       exterior_color       12

# %% [markdown]
# ### 1.1. Feature Engineering

# %%
#Adding avg_measure to the dataset
lX_train['avg_measure'] = (lX_train['Length'] + lX_train['Width']) / 2
lX_test['avg_measure'] = (lX_test['Length'] + lX_test['Width']) / 2
lX_valid['avg_measure'] = (lX_valid['Length'] + lX_valid['Width']) / 2

# %%
#All Features column
lX_train['all_feat'] = lX_train['top_features'] + lX_train['comfort_features'] 
+ lX_train['interior_features'] + lX_train['exterior_features']  + lX_train['safety_features']

lX_valid['all_feat'] = lX_valid['top_features'] + lX_valid['comfort_features'] 
+ lX_valid['interior_features'] + lX_valid['exterior_features']  + lX_valid['safety_features']

lX_test['all_feat'] = lX_test['top_features'] + lX_test['comfort_features'] 
+ lX_test['interior_features'] + lX_test['exterior_features']  + lX_test['safety_features']
# Out:
# 3241    19.0
# 2517    52.0
# 3090    34.0
# 1918    51.0
# 487     46.0
#         ...
# 1184    53.0
# 1602    49.0
# 2874    46.0
# 3242    51.0
# 2268    41.0
# Length: 1887, dtype: float64

# %%
lX_test.tail(3)
# Out:
#       myear transmission    fuel       km Valve Configuration  Turbo Charger  \
# 2874   2018       manual  diesel  54000.0                dohc           True
# 3242   2018    automatic  petrol  24123.0                dohc          False
# 2268   2014       manual  diesel  62325.0                dohc           True
#
#       Super Charger  Kerb Weight Drive Type  Seats  ...  Gear Box  \
# 2874           True  1120.000000        fwd    3.0  ...   5 speed
# 3242          False  1491.285879        fwd    4.0  ...   6 speed
# 2268           True  1491.285879        fwd    4.0  ...   6 speed
#
#       Steering Type  Front Brake Type  Rear Brake Type        Tyre Type  \
# 2874          power              disc             drum  tubeless radial
# 3242          power              disc             drum         tubeless
# 2268          power           caliper          caliper  tubeless radial
#
#      exterior_color  avg_measure  all_feat     Valves        Tread
# 2874         orange       1993.5      24.0  15.716809  1410.000000
# 3242            red       2110.0      30.0  15.843738  1454.799930
# 2268          white       2242.5      26.0  15.974877  1503.006162
#
# [3 rows x 31 columns]

# %%
#Valves featur
lX_train['Valves'] = lX_train['No of Cylinder'] * lX_train['Valves per Cylinder']
lX_test['Valves'] = lX_test['No of Cylinder'] * lX_test['Valves per Cylinder']
lX_valid['Valves'] = np.log(lX_valid['No of Cylinder'] * lX_valid['Valves per Cylinder']

# %%
lX_train['Tread'] = (lX_train['Front Tread'] + lX_train['Rear Tread'])/ 2
lX_valid['Tread'] = (lX_valid['Front Tread'] + lX_valid['Rear Tread'])/ 2
lX_test['Tread'] = (lX_test['Front Tread'] + lX_test['Rear Tread'])/ 2

# %%
to_drop = [ 'top_features', 'No of Cylinder', 'Valves per Cylinder',
       'comfort_features', 'interior_features', 'exterior_features',
       'safety_features','Length', 'Width', 'Front Tread', 'Rear Tread']

# %%
#Dropping the columns
lX_train = lX_train.drop(to_drop, axis = 1)
lX_valid = lX_valid.drop(to_drop, axis = 1)
lX_test = lX_test.drop(to_drop, axis = 1)

# %%
test.loc[2268, ['top_features','comfort_features', 'interior_features', 'exterior_features',
       'safety_features']]
# Out:
# top_features          9.0
# comfort_features     17.0
# interior_features    10.0
# exterior_features    11.0
# safety_features      20.0
# Name: 2268, dtype: object

# %% [markdown]
# ### 2.Vectorizer pipeline

# %%
#Creating the necessary objects
rf = RandomForestRegressor()
xg = XGBRegressor()
lr = LinearRegression()
ls = Lasso()
rg = Ridge()
el = ElasticNet()
lg = LGBMRegressor(boosting_type = 'rf')
cat = CatBoostRegressor(loss_function = 'MAE', eval_metric = 'MAE', verbose = 0)
gb = GradientBoostingRegressor(loss = 'absolute_error')
hgb = HistGradientBoostingRegressor(loss = 'absolute_error')
ab = AdaBoostRegressor()
et = ExtraTreesRegressor()
dt = DecisionTreeRegressor()
reg = [lr, ls, rg, el, dt, et, rf, ab, gb, hgb, xg, lg, cat]
tags = ['lr', 'ls', 'rg', 'el', 'dt', 'et', 'rf', 'ab', 'gb', 'hgb', 'xg', 'lg', 'cat']

# %%
def pipl(model, encoder,  X_train, y_train, X_test, y_test):
    pipeline = make_pipeline(encoder, model)
    
    pipeline.fit(X_train, y_train)
    train_preds = pipeline.predict(X_train)
    test_preds = pipeline.predict(X_test)
    train_score = mean_absolute_error(y_train, train_preds)
    test_score = mean_absolute_error(y_test, test_preds)
    train_percent = train_score * 100 / y_train.mean()
    test_percent = test_score * 100 / y_test.mean()
    #print("For Train-Test")
    #print("MAE% on train: ", train_percent)
    #print("MAE% on test: ", test_percent)
    return train_percent, test_percent

# %%
# %%time
bois = pipl(cat, tv, X_train, y_train, X_test, y_test)#Model performs better without scaler
print("Train MAE: ", bois[0])
print("Test MAE: ", bois[1])

# %%
scoresheet1 = pd.DataFrame(index = tags, data = {'train_score' : np.nan, 'test_score' : np.nan})

# %%
# %%time
i = 0
for regressor in reg:
    vals = pipl(regressor, sv, X_train, y_train, X_test, y_test)
    var_name = tags[i]
    scoresheet1.loc[var_name, 'train_score'] = vals[0]
    scoresheet1.loc[var_name, 'test_score'] = vals[1]
    i+=1

# %%
scoresheet1

# %%
scoresheet2 = pd.DataFrame(index = tags, data = {'train_score' : np.nan, 'test_score' : np.nan})

# %%
# %%time
i = 0
for regressor in reg:
    vals = pipl(regressor, tv, X_train, y_train, X_test, y_test)
    var_name = tags[i]
    scoresheet2.loc[var_name, 'train_score'] = vals[0]
    scoresheet2.loc[var_name, 'test_score'] = vals[1]
    i+=1
# Out:
# C:\Users\rajni\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.571e+17, tolerance: 3.449e+13
#   model = cd_fast.enet_coordinate_descent(
# Learning rate set to 0.071401
# 0:	learn: 3180150.5240153	total: 14.7ms	remaining: 14.7s
# 1:	learn: 3165050.3808187	total: 27.2ms	remaining: 13.6s
# 2:	learn: 3152325.1548726	total: 39.3ms	remaining: 13.1s
# 3:	learn: 3142567.7441732	total: 52.1ms	remaining: 13s
# 4:	learn: 3132321.4742144	total: 65.7ms	remaining: 13.1s
# 5:	learn: 3085427.5018755	total: 79.1ms	remaining: 13.1s
# 6:	learn: 3083584.3886225	total: 90.7ms	remaining: 12.9s
# 7:	learn: 3075196.5825219	total: 103ms	remaining: 12.7s
# 8:	learn: 3066814.6156667	total: 115ms	remaining: 12.6s
# 9:	learn: 3065446.5995029	total: 126ms	remaining: 12.5s
# 10:	learn: 3058913.7370376	total: 138ms	remaining: 12.4s
# 11:	learn: 3057500.6790531	total: 144ms	remaining: 11.9s
# 12:	learn: 3053593.1180276	total: 156ms	remaining: 11.9s
# 13:	learn: 3052413.1241663	total: 167ms	remaining: 11.7s
# 14:	learn: 3042889.6641348	total: 180ms	remaining: 11.8s
# 15:	learn: 3041774.4871807	total: 192ms	remaining: 11.8s
# 16:	learn: 3034682.5032848	total: 204ms	remaining: 11.8s
# 17:	learn: 3033415.1206376	total: 215ms	remaining: 11.7s
# 18:	learn: 3027774.2331366	total: 228ms	remaining: 11.8s
# 19:	learn: 3022616.9371597	total: 242ms	remaining: 11.9s
# 20:	learn: 3021714.6503885	total: 254ms	remaining: 11.8s
# 21:	learn: 3017086.9721731	total: 266ms	remaining: 11.8s
# 22:	learn: 3016267.8550060	total: 278ms	remaining: 11.8s
# 23:	learn: 3015476.3634507	total: 290ms	remaining: 11.8s
# 24:	learn: 3014667.2816900	total: 300ms	remaining: 11.7s
# 25:	learn: 3011095.7295233	total: 312ms	remaining: 11.7s
# 26:	learn: 3010294.3927441	total: 324ms	remaining: 11.7s
# 27:	learn: 3006744.6694779	total: 337ms	remaining: 11.7s
# 28:	learn: 3006011.8576711	total: 348ms	remaining: 11.7s
# 29:	learn: 2989845.7823543	total: 362ms	remaining: 11.7s
# 30:	learn: 2988883.1785499	total: 374ms	remaining: 11.7s
# 31:	learn: 2988368.2378122	total: 382ms	remaining: 11.5s
# 32:	learn: 2985192.6344035	total: 395ms	remaining: 11.6s
# 33:	learn: 2984708.9833206	total: 407ms	remaining: 11.6s
# 34:	learn: 2981882.8830580	total: 418ms	remaining: 11.5s
# 35:	learn: 2981312.1958540	total: 429ms	remaining: 11.5s
# 36:	learn: 2980771.0509954	total: 440ms	remaining: 11.5s
# 37:	learn: 2978387.2749457	total: 453ms	remaining: 11.5s
# 38:	learn: 2977804.9986424	total: 466ms	remaining: 11.5s
# 39:	learn: 2976374.6828753	total: 478ms	remaining: 11.5s
# 40:	learn: 2975594.4927010	total: 490ms	remaining: 11.5s
# 41:	learn: 2923298.2036899	total: 503ms	remaining: 11.5s
# 42:	learn: 2920584.9028628	total: 514ms	remaining: 11.4s
# 43:	learn: 2920231.7627179	total: 525ms	remaining: 11.4s
# 44:	learn: 2919781.9745188	total: 536ms	remaining: 11.4s
# 45:	learn: 2917908.1251597	total: 549ms	remaining: 11.4s
# 46:	learn: 2916234.0435209	total: 561ms	remaining: 11.4s
# 47:	learn: 2914881.9365635	total: 573ms	remaining: 11.4s
# 48:	learn: 2913228.4603475	total: 585ms	remaining: 11.4s
# 49:	learn: 2912900.5284956	total: 597ms	remaining: 11.3s
# 50:	learn: 2912554.1734373	total: 610ms	remaining: 11.4s
# 51:	learn: 2911156.4938142	total: 622ms	remaining: 11.3s
# 52:	learn: 2910876.4956984	total: 633ms	remaining: 11.3s
# 53:	learn: 2910452.3327629	total: 644ms	remaining: 11.3s
# 54:	learn: 2909091.6542986	total: 658ms	remaining: 11.3s
# 55:	learn: 2907997.6147969	total: 668ms	remaining: 11.3s
# 56:	learn: 2907292.1340654	total: 681ms	remaining: 11.3s
# 57:	learn: 2907036.2345593	total: 692ms	remaining: 11.2s
# 58:	learn: 2905677.5576051	total: 705ms	remaining: 11.2s
# 59:	learn: 2904558.6065574	total: 717ms	remaining: 11.2s
# 60:	learn: 2903412.3107257	total: 729ms	remaining: 11.2s
# 61:	learn: 2899938.9819996	total: 744ms	remaining: 11.2s
# 62:	learn: 2899754.4594974	total: 756ms	remaining: 11.2s
# 63:	learn: 2899197.9675653	total: 768ms	remaining: 11.2s
# 64:	learn: 2898061.9500520	total: 780ms	remaining: 11.2s
# 65:	learn: 2896770.0286487	total: 794ms	remaining: 11.2s
# 66:	learn: 2896482.6824915	total: 806ms	remaining: 11.2s
# 67:	learn: 2896342.1119894	total: 813ms	remaining: 11.1s
# 68:	learn: 2896175.6020878	total: 825ms	remaining: 11.1s
# 69:	learn: 2895281.7910726	total: 839ms	remaining: 11.1s
# 70:	learn: 2895124.5470296	total: 852ms	remaining: 11.1s
# 71:	learn: 2894986.0403694	total: 863ms	remaining: 11.1s
# 72:	learn: 2894118.1564285	total: 876ms	remaining: 11.1s
# 73:	learn: 2893373.9160690	total: 889ms	remaining: 11.1s
# 74:	learn: 2892708.5315574	total: 901ms	remaining: 11.1s
# 75:	learn: 2892391.6561654	total: 914ms	remaining: 11.1s
# 76:	learn: 2892288.9095662	total: 927ms	remaining: 11.1s
# 77:	learn: 2888392.6262076	total: 942ms	remaining: 11.1s
# 78:	learn: 2887922.4163696	total: 955ms	remaining: 11.1s
# 79:	learn: 2887137.9836812	total: 968ms	remaining: 11.1s
# 80:	learn: 2886433.7731475	total: 981ms	remaining: 11.1s
# 81:	learn: 2882631.7286025	total: 996ms	remaining: 11.1s
# 82:	learn: 2882290.9006608	total: 1.01s	remaining: 11.1s
# 83:	learn: 2881916.4905801	total: 1.02s	remaining: 11.1s
# 84:	learn: 2881839.0009446	total: 1.03s	remaining: 11.1s
# 85:	learn: 2881750.3119067	total: 1.04s	remaining: 11.1s
# 86:	learn: 2881387.4265366	total: 1.06s	remaining: 11.1s
# 87:	learn: 2881160.0736470	total: 1.07s	remaining: 11.1s
# 88:	learn: 2881056.9895545	total: 1.08s	remaining: 11.1s
# 89:	learn: 2880965.4944564	total: 1.09s	remaining: 11.1s
# 90:	learn: 2880598.7661349	total: 1.11s	remaining: 11.1s
# 91:	learn: 2880340.0861633	total: 1.12s	remaining: 11.1s
# 92:	learn: 2879942.4230206	total: 1.13s	remaining: 11.1s
# 93:	learn: 2876657.3796291	total: 1.15s	remaining: 11.1s
# 94:	learn: 2876356.8087516	total: 1.16s	remaining: 11s
# 95:	learn: 2875907.1680650	total: 1.17s	remaining: 11s
# 96:	learn: 2872045.0118696	total: 1.18s	remaining: 11s
# 97:	learn: 2871385.3195809	total: 1.2s	remaining: 11s
# 98:	learn: 2871161.9423640	total: 1.21s	remaining: 11s
# 99:	learn: 2871020.6753759	total: 1.22s	remaining: 11s
# 100:	learn: 2870785.0415775	total: 1.23s	remaining: 11s
# 101:	learn: 2870740.6837172	total: 1.25s	remaining: 11s
# 102:	learn: 2870404.2021955	total: 1.26s	remaining: 11s
# 103:	learn: 2870300.5275973	total: 1.27s	remaining: 11s
# 104:	learn: 2860793.4678572	total: 1.29s	remaining: 11s
# 105:	learn: 2860475.7541087	total: 1.3s	remaining: 11s
# 106:	learn: 2860390.6560769	total: 1.31s	remaining: 11s
# 107:	learn: 2860105.1657005	total: 1.32s	remaining: 10.9s
# 108:	learn: 2860044.1320921	total: 1.34s	remaining: 10.9s
# 109:	learn: 2859631.9082350	total: 1.35s	remaining: 10.9s
# 110:	learn: 2859575.1207394	total: 1.36s	remaining: 10.9s
# 111:	learn: 2859311.5573037	total: 1.38s	remaining: 10.9s
# 112:	learn: 2859153.5780375	total: 1.39s	remaining: 10.9s
# 113:	learn: 2819179.0567103	total: 1.4s	remaining: 10.9s
# 114:	learn: 2818181.5930444	total: 1.42s	remaining: 10.9s
# 115:	learn: 2818023.9864129	total: 1.43s	remaining: 10.9s
# 116:	learn: 2817995.4589709	total: 1.44s	remaining: 10.9s
# 117:	learn: 2817888.5988671	total: 1.45s	remaining: 10.9s
# 118:	learn: 2817816.8292143	total: 1.47s	remaining: 10.8s
# 119:	learn: 2817587.6168666	total: 1.48s	remaining: 10.8s
# 120:	learn: 2817498.5205870	total: 1.49s	remaining: 10.8s
# 121:	learn: 2817419.6805909	total: 1.5s	remaining: 10.8s
# 122:	learn: 2817351.3532367	total: 1.52s	remaining: 10.8s
# 123:	learn: 2816955.3516841	total: 1.53s	remaining: 10.8s
# 124:	learn: 2807246.3238795	total: 1.55s	remaining: 10.8s
# 125:	learn: 2807170.2353496	total: 1.56s	remaining: 10.8s
# 126:	learn: 2807008.1373036	total: 1.57s	remaining: 10.8s
# 127:	learn: 2806810.3795380	total: 1.58s	remaining: 10.8s
# 128:	learn: 2803930.8484165	total: 1.6s	remaining: 10.8s
# 129:	learn: 2754561.7387510	total: 1.61s	remaining: 10.8s
# 130:	learn: 2752222.7331834	total: 1.62s	remaining: 10.8s
# 131:	learn: 2752065.6717386	total: 1.64s	remaining: 10.8s
# 132:	learn: 2751937.2124262	total: 1.65s	remaining: 10.8s
# 133:	learn: 2702706.0485067	total: 1.66s	remaining: 10.8s
# 134:	learn: 2702559.7431349	total: 1.68s	remaining: 10.7s
# 135:	learn: 2702384.8412619	total: 1.69s	remaining: 10.7s
# 136:	learn: 2701689.1368258	total: 1.71s	remaining: 10.8s
# 137:	learn: 2701627.7234188	total: 1.72s	remaining: 10.7s
# 138:	learn: 2701523.5128460	total: 1.73s	remaining: 10.7s
# 139:	learn: 2701439.6858732	total: 1.74s	remaining: 10.7s
# 140:	learn: 2701358.1516437	total: 1.76s	remaining: 10.7s
# 141:	learn: 2701242.4013748	total: 1.77s	remaining: 10.7s
# 142:	learn: 2701161.4049722	total: 1.78s	remaining: 10.7s
# 143:	learn: 2701147.3974397	total: 1.79s	remaining: 10.7s
# 144:	learn: 2700996.2655624	total: 1.81s	remaining: 10.7s
# 145:	learn: 2699872.1370590	total: 1.82s	remaining: 10.6s
# 146:	learn: 2699759.9373188	total: 1.83s	remaining: 10.6s
# 147:	learn: 2697793.7824239	total: 1.85s	remaining: 10.6s
# 148:	learn: 2695773.8206538	total: 1.86s	remaining: 10.6s
# 149:	learn: 2695438.9512250	total: 1.87s	remaining: 10.6s
# 150:	learn: 2695296.5405291	total: 1.89s	remaining: 10.6s
# 151:	learn: 2693791.7217804	total: 1.9s	remaining: 10.6s
# 152:	learn: 2693664.5231173	total: 1.92s	remaining: 10.6s
# 153:	learn: 2693555.5890498	total: 1.93s	remaining: 10.6s
# 154:	learn: 2693524.1158771	total: 1.94s	remaining: 10.6s
# 155:	learn: 2693407.8392096	total: 1.95s	remaining: 10.6s
# 156:	learn: 2692093.5692092	total: 1.97s	remaining: 10.6s
# 157:	learn: 2691966.0962301	total: 1.98s	remaining: 10.5s
# 158:	learn: 2691901.6192562	total: 1.99s	remaining: 10.5s
# 159:	learn: 2691757.6807215	total: 2s	remaining: 10.5s
# 160:	learn: 2691229.1901001	total: 2.02s	remaining: 10.5s
# 161:	learn: 2691186.8648885	total: 2.03s	remaining: 10.5s
# 162:	learn: 2691078.1479322	total: 2.04s	remaining: 10.5s
# 163:	learn: 2689391.4212980	total: 2.05s	remaining: 10.5s
# 164:	learn: 2689299.2937491	total: 2.07s	remaining: 10.5s
# 165:	learn: 2689166.6940619	total: 2.08s	remaining: 10.4s
# 166:	learn: 2689145.2364296	total: 2.09s	remaining: 10.4s
# 167:	learn: 2642063.4043739	total: 2.1s	remaining: 10.4s
# 168:	learn: 2641999.4079484	total: 2.11s	remaining: 10.4s
# 169:	learn: 2641922.1882396	total: 2.12s	remaining: 10.4s
# 170:	learn: 2641869.5975670	total: 2.13s	remaining: 10.3s
# 171:	learn: 2641775.6572229	total: 2.15s	remaining: 10.3s
# 172:	learn: 2595568.1326458	total: 2.16s	remaining: 10.3s
# 173:	learn: 2594424.5709623	total: 2.17s	remaining: 10.3s
# 174:	learn: 2594376.7973726	total: 2.17s	remaining: 10.3s
# 175:	learn: 2594253.4207407	total: 2.19s	remaining: 10.2s
# 176:	learn: 2594190.6827993	total: 2.2s	remaining: 10.2s
# 177:	learn: 2594107.4864923	total: 2.21s	remaining: 10.2s
# 178:	learn: 2594016.1912276	total: 2.21s	remaining: 10.2s
# 179:	learn: 2593943.8813599	total: 2.22s	remaining: 10.1s
# 180:	learn: 2593845.4531407	total: 2.23s	remaining: 10.1s
# 181:	learn: 2593802.7303080	total: 2.24s	remaining: 10.1s
# 182:	learn: 2593718.6908575	total: 2.25s	remaining: 10.1s
# 183:	learn: 2593585.9643648	total: 2.27s	remaining: 10.1s
# 184:	learn: 2593516.0259695	total: 2.28s	remaining: 10s
# 185:	learn: 2565112.3328152	total: 2.29s	remaining: 10s
# 186:	learn: 2535517.6757696	total: 2.31s	remaining: 10s
# 187:	learn: 2535434.6454092	total: 2.32s	remaining: 10s
# 188:	learn: 2535345.2514892	total: 2.33s	remaining: 10s
# 189:	learn: 2535261.4460405	total: 2.34s	remaining: 9.98s
# 190:	learn: 2535234.2855342	total: 2.35s	remaining: 9.97s
# 191:	learn: 2535181.6267995	total: 2.37s	remaining: 9.96s
# 192:	learn: 2535107.9734280	total: 2.38s	remaining: 9.94s
# 193:	learn: 2532662.3184829	total: 2.39s	remaining: 9.93s
# 194:	learn: 2529766.5599500	total: 2.4s	remaining: 9.92s
# 195:	learn: 2529525.6956924	total: 2.42s	remaining: 9.91s
# 196:	learn: 2529456.6274814	total: 2.43s	remaining: 9.9s
# 197:	learn: 2529385.8015267	total: 2.44s	remaining: 9.88s
# 198:	learn: 2529314.2009497	total: 2.45s	remaining: 9.87s
# 199:	learn: 2529198.8477895	total: 2.46s	remaining: 9.86s
# 200:	learn: 2529038.4029100	total: 2.48s	remaining: 9.85s
# 201:	learn: 2528992.5205819	total: 2.49s	remaining: 9.83s
# 202:	learn: 2528933.3375001	total: 2.5s	remaining: 9.82s
# 203:	learn: 2505350.9452569	total: 2.51s	remaining: 9.81s
# 204:	learn: 2501299.4037156	total: 2.53s	remaining: 9.8s
# 205:	learn: 2498957.4539712	total: 2.54s	remaining: 9.8s
# 206:	learn: 2496982.2636809	total: 2.56s	remaining: 9.79s
# 207:	learn: 2496847.6978090	total: 2.57s	remaining: 9.78s
# 208:	learn: 2469941.5646025	total: 2.58s	remaining: 9.77s
# 209:	learn: 2427030.1542429	total: 2.6s	remaining: 9.76s
# 210:	learn: 2426940.3106956	total: 2.61s	remaining: 9.75s
# 211:	learn: 2426865.2746822	total: 2.62s	remaining: 9.74s
# 212:	learn: 2421556.0492373	total: 2.63s	remaining: 9.73s
# 213:	learn: 2420359.0693333	total: 2.65s	remaining: 9.72s
# 214:	learn: 2420278.7124853	total: 2.66s	remaining: 9.71s
# 215:	learn: 2420197.4934404	total: 2.67s	remaining: 9.69s
# 216:	learn: 2420116.5663457	total: 2.69s	remaining: 9.69s
# 217:	learn: 2412111.3692764	total: 2.7s	remaining: 9.69s
# 218:	learn: 2412027.6624073	total: 2.71s	remaining: 9.68s
# 219:	learn: 2411932.2320286	total: 2.73s	remaining: 9.67s
# 220:	learn: 2411809.7782293	total: 2.74s	remaining: 9.66s
# 221:	learn: 2410461.2360651	total: 2.75s	remaining: 9.65s
# 222:	learn: 2410376.7765284	total: 2.77s	remaining: 9.64s
# 223:	learn: 2405598.8854595	total: 2.78s	remaining: 9.63s
# 224:	learn: 2405554.4054635	total: 2.79s	remaining: 9.62s
# 225:	learn: 2363669.4237987	total: 2.81s	remaining: 9.61s
# 226:	learn: 2360891.2839428	total: 2.82s	remaining: 9.61s
# 227:	learn: 2360815.1765906	total: 2.83s	remaining: 9.59s
# 228:	learn: 2335628.0475618	total: 2.85s	remaining: 9.59s
# 229:	learn: 2335559.3225585	total: 2.86s	remaining: 9.57s
# 230:	learn: 2331920.2972209	total: 2.87s	remaining: 9.56s
# 231:	learn: 2291346.8882843	total: 2.89s	remaining: 9.55s
# 232:	learn: 2291034.8796236	total: 2.9s	remaining: 9.55s
# 233:	learn: 2290750.1592083	total: 2.91s	remaining: 9.54s
# 234:	learn: 2290702.1256014	total: 2.93s	remaining: 9.53s
# 235:	learn: 2290607.3773348	total: 2.94s	remaining: 9.52s
# 236:	learn: 2287464.0886057	total: 2.95s	remaining: 9.51s
# 237:	learn: 2287400.4573470	total: 2.97s	remaining: 9.5s
# 238:	learn: 2287333.5740334	total: 2.98s	remaining: 9.49s
# 239:	learn: 2287264.2877949	total: 2.99s	remaining: 9.48s
# 240:	learn: 2287184.9473069	total: 3s	remaining: 9.46s
# 241:	learn: 2247434.7227789	total: 3.02s	remaining: 9.45s
# 242:	learn: 2247346.6688244	total: 3.03s	remaining: 9.44s
# 243:	learn: 2246893.4830188	total: 3.04s	remaining: 9.42s
# 244:	learn: 2246771.7801263	total: 3.05s	remaining: 9.4s
# 245:	learn: 2207758.9912263	total: 3.06s	remaining: 9.39s
# 246:	learn: 2207699.9329006	total: 3.07s	remaining: 9.37s
# 247:	learn: 2207638.4447473	total: 3.08s	remaining: 9.35s
# 248:	learn: 2169480.0474534	total: 3.09s	remaining: 9.33s
# 249:	learn: 2131973.7569569	total: 3.1s	remaining: 9.31s
# 250:	learn: 2122934.4876906	total: 3.12s	remaining: 9.3s
# 251:	learn: 2119698.8230337	total: 3.13s	remaining: 9.28s
# 252:	learn: 2119645.5043427	total: 3.14s	remaining: 9.26s
# 253:	learn: 2083121.1000236	total: 3.15s	remaining: 9.25s
# 254:	learn: 2081738.1954932	total: 3.16s	remaining: 9.23s
# 255:	learn: 2045855.8918215	total: 3.17s	remaining: 9.22s
# 256:	learn: 2045772.9921744	total: 3.18s	remaining: 9.2s
# 257:	learn: 2045703.5662057	total: 3.19s	remaining: 9.19s
# 258:	learn: 2043536.5455771	total: 3.21s	remaining: 9.18s
# 259:	learn: 2043484.8271589	total: 3.22s	remaining: 9.17s
# 260:	learn: 2040416.5710667	total: 3.23s	remaining: 9.16s
# 261:	learn: 2040331.3550550	total: 3.25s	remaining: 9.15s
# 262:	learn: 2005326.8003605	total: 3.26s	remaining: 9.14s
# 263:	learn: 2004791.8056044	total: 3.28s	remaining: 9.13s
# 264:	learn: 2004726.0109708	total: 3.29s	remaining: 9.12s
# 265:	learn: 2004686.9838607	total: 3.3s	remaining: 9.1s
# 266:	learn: 2004626.5008298	total: 3.31s	remaining: 9.09s
# 267:	learn: 2004001.7356900	total: 3.33s	remaining: 9.09s
# 268:	learn: 2003833.3793901	total: 3.34s	remaining: 9.07s
# 269:	learn: 2002334.9765672	total: 3.35s	remaining: 9.06s
# 270:	learn: 1967983.8152744	total: 3.37s	remaining: 9.05s
# 271:	learn: 1952400.6014784	total: 3.38s	remaining: 9.04s
# 272:	learn: 1919185.0471396	total: 3.39s	remaining: 9.03s
# 273:	learn: 1919122.2506426	total: 3.4s	remaining: 9.02s
# 274:	learn: 1919060.4615827	total: 3.42s	remaining: 9.01s
# 275:	learn: 1917217.9018406	total: 3.43s	remaining: 9.01s
# 276:	learn: 1916819.4713782	total: 3.45s	remaining: 8.99s
# 277:	learn: 1915012.8320048	total: 3.46s	remaining: 8.98s
# 278:	learn: 1914941.9111909	total: 3.47s	remaining: 8.98s
# 279:	learn: 1914883.3775682	total: 3.49s	remaining: 8.96s
# 280:	learn: 1914720.6245690	total: 3.5s	remaining: 8.95s
# 281:	learn: 1914666.9846949	total: 3.51s	remaining: 8.94s
# 282:	learn: 1914617.4448202	total: 3.52s	remaining: 8.93s
# 283:	learn: 1914199.4966841	total: 3.54s	remaining: 8.91s
# 284:	learn: 1909386.8597897	total: 3.55s	remaining: 8.9s
# 285:	learn: 1909349.3306853	total: 3.56s	remaining: 8.89s
# 286:	learn: 1876706.3216136	total: 3.58s	remaining: 8.88s
# 287:	learn: 1873690.3290265	total: 3.59s	remaining: 8.87s
# 288:	learn: 1841163.2672413	total: 3.6s	remaining: 8.87s
# 289:	learn: 1826856.6486001	total: 3.62s	remaining: 8.85s
# 290:	learn: 1824187.1875451	total: 3.63s	remaining: 8.85s
# 291:	learn: 1810962.1606134	total: 3.64s	remaining: 8.83s
# 292:	learn: 1810728.6279070	total: 3.66s	remaining: 8.82s
# 293:	learn: 1810669.5835607	total: 3.67s	remaining: 8.81s
# 294:	learn: 1810623.0465930	total: 3.68s	remaining: 8.8s
# 295:	learn: 1810178.0101573	total: 3.69s	remaining: 8.79s
# 296:	learn: 1810103.7736481	total: 3.71s	remaining: 8.78s
# 297:	learn: 1810059.0814759	total: 3.72s	remaining: 8.76s
# 298:	learn: 1809876.9914672	total: 3.73s	remaining: 8.76s
# 299:	learn: 1809831.3677969	total: 3.75s	remaining: 8.74s
# 300:	learn: 1779101.2972422	total: 3.76s	remaining: 8.73s
# 301:	learn: 1756713.2001447	total: 3.77s	remaining: 8.72s
# 302:	learn: 1756704.6373047	total: 3.78s	remaining: 8.71s
# 303:	learn: 1756523.2483420	total: 3.8s	remaining: 8.7s
# 304:	learn: 1756514.5400034	total: 3.81s	remaining: 8.68s
# 305:	learn: 1726521.8164006	total: 3.82s	remaining: 8.67s
# 306:	learn: 1726458.7187320	total: 3.84s	remaining: 8.66s
# 307:	learn: 1697002.7153461	total: 3.85s	remaining: 8.65s
# 308:	learn: 1667918.4834697	total: 3.87s	remaining: 8.64s
# 309:	learn: 1639578.0384740	total: 3.88s	remaining: 8.64s
# 310:	learn: 1611703.5392230	total: 3.9s	remaining: 8.63s
# 311:	learn: 1584610.1891275	total: 3.91s	remaining: 8.63s
# 312:	learn: 1558040.7184963	total: 3.93s	remaining: 8.62s
# 313:	learn: 1531985.5043694	total: 3.94s	remaining: 8.61s
# 314:	learn: 1506435.1698922	total: 3.96s	remaining: 8.61s
# 315:	learn: 1481380.5717688	total: 3.97s	remaining: 8.6s
# 316:	learn: 1456812.7888455	total: 3.99s	remaining: 8.59s
# 317:	learn: 1432723.1117003	total: 4s	remaining: 8.58s
# 318:	learn: 1409103.0331210	total: 4.02s	remaining: 8.57s
# 319:	learn: 1383316.4855961	total: 4.03s	remaining: 8.56s
# 320:	learn: 1360560.7856975	total: 4.04s	remaining: 8.55s
# 321:	learn: 1338249.9685221	total: 4.06s	remaining: 8.54s
# 322:	learn: 1313916.1060899	total: 4.07s	remaining: 8.53s
# 323:	learn: 1292074.3318959	total: 4.08s	remaining: 8.52s
# 324:	learn: 1271002.7213912	total: 4.1s	remaining: 8.51s
# 325:	learn: 1250031.3173137	total: 4.12s	remaining: 8.51s
# 326:	learn: 1227482.4597684	total: 4.13s	remaining: 8.5s
# 327:	learn: 1207328.0306944	total: 4.14s	remaining: 8.49s
# 328:	learn: 1187594.0490084	total: 4.16s	remaining: 8.48s
# 329:	learn: 1187037.6860837	total: 4.17s	remaining: 8.47s
# 330:	learn: 1167725.0950772	total: 4.18s	remaining: 8.46s
# 331:	learn: 1163319.9296028	total: 4.2s	remaining: 8.45s
# 332:	learn: 1144491.7725418	total: 4.21s	remaining: 8.44s
# 333:	learn: 1124015.3512798	total: 4.23s	remaining: 8.43s
# 334:	learn: 1106062.9581334	total: 4.24s	remaining: 8.42s
# 335:	learn: 1088311.1159909	total: 4.25s	remaining: 8.41s
# 336:	learn: 1069013.7056855	total: 4.27s	remaining: 8.4s
# 337:	learn: 1052007.0480878	total: 4.28s	remaining: 8.38s
# 338:	learn: 1038294.4037070	total: 4.29s	remaining: 8.38s
# 339:	learn: 1021921.1513510	total: 4.31s	remaining: 8.37s
# 340:	learn: 1009137.1722310	total: 4.32s	remaining: 8.36s
# 341:	learn: 993300.6435966	total: 4.34s	remaining: 8.35s
# 342:	learn: 977680.7634878	total: 4.35s	remaining: 8.34s
# 343:	learn: 962483.6099316	total: 4.37s	remaining: 8.32s
# 344:	learn: 950939.4954883	total: 4.38s	remaining: 8.31s
# 345:	learn: 936241.8676829	total: 4.39s	remaining: 8.3s
# 346:	learn: 921845.7791841	total: 4.41s	remaining: 8.29s
# 347:	learn: 911444.2853119	total: 4.42s	remaining: 8.28s
# 348:	learn: 901374.2203893	total: 4.43s	remaining: 8.27s
# 349:	learn: 887449.1548572	total: 4.45s	remaining: 8.26s
# 350:	learn: 873966.5619496	total: 4.46s	remaining: 8.25s
# 351:	learn: 860765.2987591	total: 4.48s	remaining: 8.24s
# 352:	learn: 847559.3630957	total: 4.49s	remaining: 8.23s
# 353:	learn: 846516.4656034	total: 4.5s	remaining: 8.22s
# 354:	learn: 833772.7309870	total: 4.52s	remaining: 8.21s
# 355:	learn: 821387.1567990	total: 4.53s	remaining: 8.2s
# 356:	learn: 809263.6634888	total: 4.54s	remaining: 8.18s
# 357:	learn: 796610.9662402	total: 4.56s	remaining: 8.17s
# 358:	learn: 795305.3336559	total: 4.57s	remaining: 8.16s
# 359:	learn: 795181.7230321	total: 4.58s	remaining: 8.15s
# 360:	learn: 783467.3224598	total: 4.6s	remaining: 8.14s
# 361:	learn: 775682.1285033	total: 4.61s	remaining: 8.13s
# 362:	learn: 764434.1336762	total: 4.62s	remaining: 8.12s
# 363:	learn: 753427.7688651	total: 4.64s	remaining: 8.1s
# 364:	learn: 753296.6896068	total: 4.65s	remaining: 8.1s
# 365:	learn: 753100.0471962	total: 4.67s	remaining: 8.08s
# 366:	learn: 752987.1287927	total: 4.68s	remaining: 8.07s
# 367:	learn: 752606.9198284	total: 4.7s	remaining: 8.06s
# 368:	learn: 752509.0381140	total: 4.71s	remaining: 8.05s
# 369:	learn: 752401.5045499	total: 4.72s	remaining: 8.04s
# 370:	learn: 752204.8787008	total: 4.73s	remaining: 8.03s
# 371:	learn: 752061.4185805	total: 4.75s	remaining: 8.01s
# 372:	learn: 751977.0352955	total: 4.76s	remaining: 8s
# 373:	learn: 751880.0448719	total: 4.77s	remaining: 7.99s
# 374:	learn: 751752.5631960	total: 4.79s	remaining: 7.98s
# 375:	learn: 751674.1886082	total: 4.8s	remaining: 7.96s
# 376:	learn: 751598.3321080	total: 4.81s	remaining: 7.95s
# 377:	learn: 751572.1533179	total: 4.82s	remaining: 7.93s
# 378:	learn: 751463.3000302	total: 4.83s	remaining: 7.92s
# 379:	learn: 751396.8778957	total: 4.85s	remaining: 7.91s
# 380:	learn: 751310.5646032	total: 4.86s	remaining: 7.9s
# 381:	learn: 751221.7680957	total: 4.87s	remaining: 7.88s
# 382:	learn: 751155.7544538	total: 4.88s	remaining: 7.87s
# 383:	learn: 751083.2454109	total: 4.9s	remaining: 7.86s
# 384:	learn: 750999.2163892	total: 4.91s	remaining: 7.85s
# 385:	learn: 750892.8425888	total: 4.93s	remaining: 7.84s
# 386:	learn: 750821.3472796	total: 4.94s	remaining: 7.83s
# 387:	learn: 750735.1142815	total: 4.95s	remaining: 7.81s
# 388:	learn: 750675.6718648	total: 4.97s	remaining: 7.8s
# 389:	learn: 750600.5551779	total: 4.98s	remaining: 7.79s
# 390:	learn: 750541.6147743	total: 4.99s	remaining: 7.77s
# 391:	learn: 750469.4067445	total: 5s	remaining: 7.76s
# 392:	learn: 750379.3875242	total: 5.01s	remaining: 7.75s
# 393:	learn: 750348.0759273	total: 5.03s	remaining: 7.73s
# 394:	learn: 750261.3308985	total: 5.04s	remaining: 7.72s
# 395:	learn: 750187.7414380	total: 5.05s	remaining: 7.71s
# 396:	learn: 750124.1850587	total: 5.06s	remaining: 7.69s
# 397:	learn: 741193.4412095	total: 5.08s	remaining: 7.68s
# 398:	learn: 734045.6250415	total: 5.09s	remaining: 7.67s
# 399:	learn: 733777.7515329	total: 5.1s	remaining: 7.66s
# 400:	learn: 733738.3757954	total: 5.12s	remaining: 7.64s
# 401:	learn: 733703.1741288	total: 5.13s	remaining: 7.63s
# 402:	learn: 722435.3046808	total: 5.14s	remaining: 7.62s
# 403:	learn: 722333.9371844	total: 5.16s	remaining: 7.61s
# 404:	learn: 722275.1907132	total: 5.17s	remaining: 7.59s
# 405:	learn: 722190.5376250	total: 5.18s	remaining: 7.58s
# 406:	learn: 722127.1785770	total: 5.19s	remaining: 7.57s
# 407:	learn: 722059.7661045	total: 5.21s	remaining: 7.55s
# 408:	learn: 721998.7533353	total: 5.22s	remaining: 7.54s
# 409:	learn: 721918.9582582	total: 5.23s	remaining: 7.53s
# 410:	learn: 721847.7469938	total: 5.24s	remaining: 7.51s
# 411:	learn: 721797.2038932	total: 5.25s	remaining: 7.5s
# 412:	learn: 721732.9840381	total: 5.27s	remaining: 7.49s
# 413:	learn: 721663.0482743	total: 5.28s	remaining: 7.47s
# 414:	learn: 721589.6827044	total: 5.29s	remaining: 7.46s
# 415:	learn: 721525.4311710	total: 5.31s	remaining: 7.45s
# 416:	learn: 721465.2012358	total: 5.32s	remaining: 7.43s
# 417:	learn: 719787.7870476	total: 5.33s	remaining: 7.43s
# 418:	learn: 713101.4796299	total: 5.35s	remaining: 7.41s
# 419:	learn: 709698.2862288	total: 5.36s	remaining: 7.4s
# 420:	learn: 703384.1898780	total: 5.37s	remaining: 7.39s
# 421:	learn: 703280.1540446	total: 5.38s	remaining: 7.38s
# 422:	learn: 692819.4846716	total: 5.4s	remaining: 7.37s
# 423:	learn: 692712.8994022	total: 5.41s	remaining: 7.35s
# 424:	learn: 692604.3128848	total: 5.43s	remaining: 7.34s
# 425:	learn: 686421.9822811	total: 5.44s	remaining: 7.33s
# 426:	learn: 686354.7442820	total: 5.45s	remaining: 7.32s
# 427:	learn: 686287.8093488	total: 5.47s	remaining: 7.31s
# 428:	learn: 675985.1046809	total: 5.48s	remaining: 7.29s
# 429:	learn: 675878.7508380	total: 5.49s	remaining: 7.28s
# 430:	learn: 675844.3059170	total: 5.5s	remaining: 7.27s
# 431:	learn: 675732.2569684	total: 5.52s	remaining: 7.26s
# 432:	learn: 675704.5213863	total: 5.53s	remaining: 7.24s
# 433:	learn: 673300.4764339	total: 5.54s	remaining: 7.23s
# 434:	learn: 663442.8242314	total: 5.56s	remaining: 7.22s
# 435:	learn: 663384.6248599	total: 5.57s	remaining: 7.21s
# 436:	learn: 663318.0195426	total: 5.59s	remaining: 7.2s
# 437:	learn: 663264.5006992	total: 5.6s	remaining: 7.18s
# 438:	learn: 658226.4182104	total: 5.61s	remaining: 7.17s
# 439:	learn: 658187.9710399	total: 5.63s	remaining: 7.16s
# 440:	learn: 647863.6398039	total: 5.64s	remaining: 7.15s
# 441:	learn: 647752.9372828	total: 5.65s	remaining: 7.14s
# 442:	learn: 638692.3716077	total: 5.67s	remaining: 7.13s
# 443:	learn: 629845.3014972	total: 5.68s	remaining: 7.12s
# 444:	learn: 619756.3322246	total: 5.7s	remaining: 7.11s
# 445:	learn: 611287.6186417	total: 5.71s	remaining: 7.09s
# 446:	learn: 611117.0406061	total: 5.72s	remaining: 7.08s
# 447:	learn: 605967.1489733	total: 5.74s	remaining: 7.07s
# 448:	learn: 605878.2527628	total: 5.75s	remaining: 7.06s
# 449:	learn: 605806.6350148	total: 5.76s	remaining: 7.05s
# 450:	learn: 605544.7713585	total: 5.78s	remaining: 7.03s
# 451:	learn: 605494.7595015	total: 5.79s	remaining: 7.02s
# 452:	learn: 605434.6395723	total: 5.8s	remaining: 7.01s
# 453:	learn: 604738.0462447	total: 5.82s	remaining: 7s
# 454:	learn: 604664.6385839	total: 5.83s	remaining: 6.98s
# 455:	learn: 604498.5925846	total: 5.84s	remaining: 6.97s
# 456:	learn: 604465.5482729	total: 5.85s	remaining: 6.96s
# 457:	learn: 604399.0839780	total: 5.87s	remaining: 6.94s
# 458:	learn: 596583.2588015	total: 5.88s	remaining: 6.93s
# 459:	learn: 596518.1911293	total: 5.89s	remaining: 6.92s
# 460:	learn: 594619.3755196	total: 5.91s	remaining: 6.91s
# 461:	learn: 594535.2974586	total: 5.92s	remaining: 6.89s
# 462:	learn: 594525.5028165	total: 5.93s	remaining: 6.88s
# 463:	learn: 594485.1096950	total: 5.94s	remaining: 6.87s
# 464:	learn: 589992.8421722	total: 5.96s	remaining: 6.86s
# 465:	learn: 589749.1869467	total: 5.97s	remaining: 6.84s
# 466:	learn: 582309.7346075	total: 5.99s	remaining: 6.83s
# 467:	learn: 582267.4596098	total: 6s	remaining: 6.82s
# 468:	learn: 582245.8399613	total: 6.01s	remaining: 6.8s
# 469:	learn: 581738.8800466	total: 6.02s	remaining: 6.79s
# 470:	learn: 581667.7890064	total: 6.04s	remaining: 6.78s
# 471:	learn: 581612.4834140	total: 6.05s	remaining: 6.77s
# 472:	learn: 581018.0489739	total: 6.06s	remaining: 6.76s
# 473:	learn: 580954.2699424	total: 6.08s	remaining: 6.75s
# 474:	learn: 580927.6114216	total: 6.09s	remaining: 6.73s
# 475:	learn: 580875.6376952	total: 6.1s	remaining: 6.72s
# 476:	learn: 580843.4824720	total: 6.11s	remaining: 6.7s
# 477:	learn: 580774.9081361	total: 6.13s	remaining: 6.69s
# 478:	learn: 580701.3054746	total: 6.14s	remaining: 6.68s
# 479:	learn: 580686.0673957	total: 6.15s	remaining: 6.67s
# 480:	learn: 573146.8027607	total: 6.17s	remaining: 6.65s
# 481:	learn: 573052.0528704	total: 6.18s	remaining: 6.64s
# 482:	learn: 572603.6489674	total: 6.19s	remaining: 6.63s
# 483:	learn: 572526.9195067	total: 6.21s	remaining: 6.62s
# 484:	learn: 572403.5150721	total: 6.22s	remaining: 6.6s
# 485:	learn: 572350.1515811	total: 6.23s	remaining: 6.59s
# 486:	learn: 572318.9048296	total: 6.24s	remaining: 6.58s
# 487:	learn: 571940.8634100	total: 6.26s	remaining: 6.57s
# 488:	learn: 571857.7277533	total: 6.27s	remaining: 6.55s
# 489:	learn: 571477.3317407	total: 6.29s	remaining: 6.54s
# 490:	learn: 571443.1133727	total: 6.3s	remaining: 6.53s
# 491:	learn: 569771.4989853	total: 6.31s	remaining: 6.51s
# 492:	learn: 569718.8179187	total: 6.32s	remaining: 6.5s
# 493:	learn: 569705.8886536	total: 6.33s	remaining: 6.49s
# 494:	learn: 562737.1956018	total: 6.35s	remaining: 6.47s
# 495:	learn: 562669.8094187	total: 6.36s	remaining: 6.46s
# 496:	learn: 561263.3522814	total: 6.37s	remaining: 6.45s
# 497:	learn: 561182.6292913	total: 6.39s	remaining: 6.44s
# 498:	learn: 561163.7930621	total: 6.4s	remaining: 6.42s
# 499:	learn: 561086.9895734	total: 6.41s	remaining: 6.41s
# 500:	learn: 560720.6688568	total: 6.42s	remaining: 6.4s
# 501:	learn: 560672.1267384	total: 6.44s	remaining: 6.38s
# 502:	learn: 560661.2133226	total: 6.45s	remaining: 6.37s
# 503:	learn: 560437.8555249	total: 6.46s	remaining: 6.36s
# 504:	learn: 560399.7811799	total: 6.47s	remaining: 6.34s
# 505:	learn: 559123.0626960	total: 6.49s	remaining: 6.33s
# 506:	learn: 552392.3009563	total: 6.5s	remaining: 6.32s
# 507:	learn: 552331.0146191	total: 6.51s	remaining: 6.31s
# 508:	learn: 552195.9626267	total: 6.53s	remaining: 6.29s
# 509:	learn: 552143.9179892	total: 6.54s	remaining: 6.28s
# 510:	learn: 552055.4546123	total: 6.55s	remaining: 6.27s
# 511:	learn: 552014.7678933	total: 6.57s	remaining: 6.26s
# 512:	learn: 551565.5711646	total: 6.58s	remaining: 6.25s
# 513:	learn: 551559.6506426	total: 6.59s	remaining: 6.23s
# 514:	learn: 551209.6563797	total: 6.6s	remaining: 6.22s
# 515:	learn: 551150.8691083	total: 6.62s	remaining: 6.21s
# 516:	learn: 551115.2400899	total: 6.63s	remaining: 6.19s
# 517:	learn: 551026.6859351	total: 6.64s	remaining: 6.18s
# 518:	learn: 551003.4516938	total: 6.66s	remaining: 6.17s
# 519:	learn: 550900.6921689	total: 6.67s	remaining: 6.16s
# 520:	learn: 550581.5821067	total: 6.68s	remaining: 6.14s
# 521:	learn: 550557.3665419	total: 6.7s	remaining: 6.13s
# 522:	learn: 550451.5470500	total: 6.71s	remaining: 6.12s
# 523:	learn: 550374.6021309	total: 6.72s	remaining: 6.11s
# 524:	learn: 550182.2951844	total: 6.74s	remaining: 6.1s
# 525:	learn: 550174.4980144	total: 6.75s	remaining: 6.08s
# 526:	learn: 550109.3474699	total: 6.76s	remaining: 6.07s
# 527:	learn: 549908.3610895	total: 6.78s	remaining: 6.06s
# 528:	learn: 549522.1268762	total: 6.79s	remaining: 6.04s
# 529:	learn: 549500.5343370	total: 6.8s	remaining: 6.03s
# 530:	learn: 549179.0744022	total: 6.82s	remaining: 6.02s
# 531:	learn: 549098.1661786	total: 6.83s	remaining: 6.01s
# 532:	learn: 547183.8806882	total: 6.84s	remaining: 6s
# 533:	learn: 547136.7766675	total: 6.86s	remaining: 5.98s
# 534:	learn: 547114.7101144	total: 6.87s	remaining: 5.97s
# 535:	learn: 540561.2291381	total: 6.89s	remaining: 5.96s
# 536:	learn: 540470.3898492	total: 6.9s	remaining: 5.95s
# 537:	learn: 540414.3202776	total: 6.92s	remaining: 5.94s
# 538:	learn: 540360.0328587	total: 6.93s	remaining: 5.93s
# 539:	learn: 540310.4475497	total: 6.95s	remaining: 5.92s
# 540:	learn: 540130.8029718	total: 6.96s	remaining: 5.91s
# 541:	learn: 540087.5380523	total: 6.97s	remaining: 5.89s
# 542:	learn: 540041.5924648	total: 6.99s	remaining: 5.88s
# 543:	learn: 539740.3544048	total: 7s	remaining: 5.87s
# 544:	learn: 538585.4241640	total: 7.01s	remaining: 5.86s
# 545:	learn: 538533.5448478	total: 7.03s	remaining: 5.84s
# 546:	learn: 538486.5507078	total: 7.04s	remaining: 5.83s
# 547:	learn: 538400.1782719	total: 7.05s	remaining: 5.82s
# 548:	learn: 531199.6142397	total: 7.07s	remaining: 5.81s
# 549:	learn: 531146.4128170	total: 7.08s	remaining: 5.79s
# 550:	learn: 531105.7752309	total: 7.09s	remaining: 5.78s
# 551:	learn: 531039.7239235	total: 7.11s	remaining: 5.77s
# 552:	learn: 530964.1606676	total: 7.12s	remaining: 5.75s
# 553:	learn: 527628.3190989	total: 7.13s	remaining: 5.74s
# 554:	learn: 525958.8564692	total: 7.15s	remaining: 5.73s
# 555:	learn: 525749.1862394	total: 7.16s	remaining: 5.72s
# 556:	learn: 525694.9957871	total: 7.17s	remaining: 5.71s
# 557:	learn: 525582.9319870	total: 7.19s	remaining: 5.69s
# 558:	learn: 525564.3648011	total: 7.2s	remaining: 5.68s
# 559:	learn: 522212.7512260	total: 7.21s	remaining: 5.67s
# 560:	learn: 515805.1876172	total: 7.23s	remaining: 5.66s
# 561:	learn: 515752.8586563	total: 7.24s	remaining: 5.64s
# 562:	learn: 509890.0351542	total: 7.25s	remaining: 5.63s
# 563:	learn: 509243.9262804	total: 7.27s	remaining: 5.62s
# 564:	learn: 509191.6891860	total: 7.28s	remaining: 5.61s
# 565:	learn: 509186.7627522	total: 7.29s	remaining: 5.59s
# 566:	learn: 509111.3692350	total: 7.3s	remaining: 5.58s
# 567:	learn: 509105.8832164	total: 7.32s	remaining: 5.57s
# 568:	learn: 508920.0554833	total: 7.33s	remaining: 5.55s
# 569:	learn: 508733.5365391	total: 7.34s	remaining: 5.54s
# 570:	learn: 502183.4606219	total: 7.36s	remaining: 5.53s
# 571:	learn: 501947.3144838	total: 7.37s	remaining: 5.52s
# 572:	learn: 501772.5217384	total: 7.39s	remaining: 5.5s
# 573:	learn: 501723.7963785	total: 7.4s	remaining: 5.49s
# 574:	learn: 501629.1710680	total: 7.41s	remaining: 5.48s
# 575:	learn: 500572.3711121	total: 7.43s	remaining: 5.47s
# 576:	learn: 497617.2380513	total: 7.44s	remaining: 5.46s
# 577:	learn: 497574.7125336	total: 7.45s	remaining: 5.44s
# 578:	learn: 497523.1225313	total: 7.47s	remaining: 5.43s
# 579:	learn: 497504.7643525	total: 7.48s	remaining: 5.42s
# 580:	learn: 497287.1850607	total: 7.49s	remaining: 5.4s
# 581:	learn: 497085.5445008	total: 7.5s	remaining: 5.39s
# 582:	learn: 496875.9192609	total: 7.52s	remaining: 5.38s
# 583:	learn: 496518.7420821	total: 7.53s	remaining: 5.37s
# 584:	learn: 496513.1607794	total: 7.54s	remaining: 5.35s
# 585:	learn: 496460.8862638	total: 7.56s	remaining: 5.34s
# 586:	learn: 496397.4159039	total: 7.57s	remaining: 5.33s
# 587:	learn: 490242.5614576	total: 7.58s	remaining: 5.32s
# 588:	learn: 490044.6120176	total: 7.6s	remaining: 5.3s
# 589:	learn: 489719.2214714	total: 7.61s	remaining: 5.29s
# 590:	learn: 489616.1850836	total: 7.63s	remaining: 5.28s
# 591:	learn: 489574.1600777	total: 7.64s	remaining: 5.26s
# 592:	learn: 489540.6542158	total: 7.65s	remaining: 5.25s
# 593:	learn: 489505.9855135	total: 7.67s	remaining: 5.24s
# 594:	learn: 488656.5144228	total: 7.68s	remaining: 5.23s
# 595:	learn: 488569.5794714	total: 7.69s	remaining: 5.21s
# 596:	learn: 488472.4697339	total: 7.71s	remaining: 5.2s
# 597:	learn: 488340.6940089	total: 7.72s	remaining: 5.19s
# 598:	learn: 482510.0628009	total: 7.74s	remaining: 5.18s
# 599:	learn: 482361.2780119	total: 7.75s	remaining: 5.17s
# 600:	learn: 482130.1453064	total: 7.76s	remaining: 5.15s
# 601:	learn: 482074.4207502	total: 7.78s	remaining: 5.14s
# 602:	learn: 482071.0619881	total: 7.79s	remaining: 5.13s
# 603:	learn: 482067.8221727	total: 7.8s	remaining: 5.11s
# 604:	learn: 480525.9327548	total: 7.81s	remaining: 5.1s
# 605:	learn: 480483.5059809	total: 7.82s	remaining: 5.09s
# 606:	learn: 480332.7019543	total: 7.84s	remaining: 5.07s
# 607:	learn: 480152.4646395	total: 7.85s	remaining: 5.06s
# 608:	learn: 474494.3689597	total: 7.86s	remaining: 5.05s
# 609:	learn: 474403.3973557	total: 7.88s	remaining: 5.04s
# 610:	learn: 474348.4886186	total: 7.89s	remaining: 5.02s
# 611:	learn: 474230.7012115	total: 7.91s	remaining: 5.01s
# 612:	learn: 474157.2393775	total: 7.92s	remaining: 5s
# 613:	learn: 474154.0617790	total: 7.93s	remaining: 4.99s
# 614:	learn: 474069.9265519	total: 7.95s	remaining: 4.97s
# 615:	learn: 473994.0939744	total: 7.96s	remaining: 4.96s
# 616:	learn: 473837.6379917	total: 7.97s	remaining: 4.95s
# 617:	learn: 473764.1475867	total: 7.99s	remaining: 4.94s
# 618:	learn: 467320.4343485	total: 8s	remaining: 4.92s
# 619:	learn: 461540.9485499	total: 8.02s	remaining: 4.91s
# 620:	learn: 461468.7138374	total: 8.03s	remaining: 4.9s
# 621:	learn: 456146.8464530	total: 8.04s	remaining: 4.89s
# 622:	learn: 455281.4173292	total: 8.06s	remaining: 4.88s
# 623:	learn: 455178.1363160	total: 8.07s	remaining: 4.86s
# 624:	learn: 449198.1764544	total: 8.08s	remaining: 4.85s
# 625:	learn: 444122.9389321	total: 8.1s	remaining: 4.84s
# 626:	learn: 444051.5009962	total: 8.11s	remaining: 4.83s
# 627:	learn: 439068.7184509	total: 8.13s	remaining: 4.81s
# 628:	learn: 438028.1470151	total: 8.14s	remaining: 4.8s
# 629:	learn: 437882.9448687	total: 8.16s	remaining: 4.79s
# 630:	learn: 437836.0839457	total: 8.17s	remaining: 4.78s
# 631:	learn: 437696.7795268	total: 8.18s	remaining: 4.76s
# 632:	learn: 435261.0257278	total: 8.2s	remaining: 4.75s
# 633:	learn: 435257.7570346	total: 8.21s	remaining: 4.74s
# 634:	learn: 430471.9957810	total: 8.22s	remaining: 4.73s
# 635:	learn: 430467.1185049	total: 8.23s	remaining: 4.71s
# 636:	learn: 430362.5367368	total: 8.25s	remaining: 4.7s
# 637:	learn: 430311.8587908	total: 8.26s	remaining: 4.69s
# 638:	learn: 430241.0834271	total: 8.27s	remaining: 4.67s
# 639:	learn: 430229.6552455	total: 8.29s	remaining: 4.66s
# 640:	learn: 425277.4491212	total: 8.3s	remaining: 4.65s
# 641:	learn: 420695.3258340	total: 8.31s	remaining: 4.64s
# 642:	learn: 420642.3247582	total: 8.33s	remaining: 4.62s
# 643:	learn: 416185.5011182	total: 8.34s	remaining: 4.61s
# 644:	learn: 416158.3657015	total: 8.35s	remaining: 4.6s
# 645:	learn: 415619.4257267	total: 8.37s	remaining: 4.58s
# 646:	learn: 415549.3922983	total: 8.38s	remaining: 4.57s
# 647:	learn: 415378.8459292	total: 8.39s	remaining: 4.56s
# 648:	learn: 415324.7912715	total: 8.41s	remaining: 4.55s
# 649:	learn: 415197.6527992	total: 8.42s	remaining: 4.53s
# 650:	learn: 410814.5646459	total: 8.44s	remaining: 4.52s
# 651:	learn: 410749.6935789	total: 8.45s	remaining: 4.51s
# 652:	learn: 410680.2720474	total: 8.46s	remaining: 4.5s
# 653:	learn: 410650.8630338	total: 8.47s	remaining: 4.48s
# 654:	learn: 410617.5971575	total: 8.49s	remaining: 4.47s
# 655:	learn: 410364.2505137	total: 8.5s	remaining: 4.46s
# 656:	learn: 410301.4770298	total: 8.51s	remaining: 4.45s
# 657:	learn: 410268.0428663	total: 8.53s	remaining: 4.43s
# 658:	learn: 405781.4259013	total: 8.54s	remaining: 4.42s
# 659:	learn: 405766.8286017	total: 8.55s	remaining: 4.41s
# 660:	learn: 405726.3167963	total: 8.56s	remaining: 4.39s
# 661:	learn: 405669.3438312	total: 8.58s	remaining: 4.38s
# 662:	learn: 405575.7539325	total: 8.59s	remaining: 4.37s
# 663:	learn: 401153.4323742	total: 8.61s	remaining: 4.36s
# 664:	learn: 396822.5055078	total: 8.62s	remaining: 4.34s
# 665:	learn: 393304.9314418	total: 8.63s	remaining: 4.33s
# 666:	learn: 389360.6900389	total: 8.65s	remaining: 4.32s
# 667:	learn: 389316.3919827	total: 8.66s	remaining: 4.3s
# 668:	learn: 389278.8579243	total: 8.68s	remaining: 4.29s
# 669:	learn: 389177.4924928	total: 8.69s	remaining: 4.28s
# 670:	learn: 388889.7787582	total: 8.7s	remaining: 4.27s
# 671:	learn: 387527.0324515	total: 8.72s	remaining: 4.25s
# 672:	learn: 387459.9379499	total: 8.73s	remaining: 4.24s
# 673:	learn: 386809.6174570	total: 8.74s	remaining: 4.23s
# 674:	learn: 386700.9924564	total: 8.76s	remaining: 4.22s
# 675:	learn: 386362.4356503	total: 8.77s	remaining: 4.2s
# 676:	learn: 386289.6992863	total: 8.78s	remaining: 4.19s
# 677:	learn: 385977.9430872	total: 8.8s	remaining: 4.18s
# 678:	learn: 385893.7691046	total: 8.81s	remaining: 4.17s
# 679:	learn: 385800.7037643	total: 8.83s	remaining: 4.15s
# 680:	learn: 385721.0382677	total: 8.84s	remaining: 4.14s
# 681:	learn: 382429.0875235	total: 8.85s	remaining: 4.13s
# 682:	learn: 382053.1991244	total: 8.87s	remaining: 4.12s
# 683:	learn: 382044.0427065	total: 8.88s	remaining: 4.1s
# 684:	learn: 381749.2386153	total: 8.89s	remaining: 4.09s
# 685:	learn: 381741.0363520	total: 8.9s	remaining: 4.08s
# 686:	learn: 381555.0120855	total: 8.92s	remaining: 4.06s
# 687:	learn: 380593.3496726	total: 8.93s	remaining: 4.05s
# 688:	learn: 380562.7768469	total: 8.95s	remaining: 4.04s
# 689:	learn: 380530.0401366	total: 8.96s	remaining: 4.02s
# 690:	learn: 380473.1367601	total: 8.97s	remaining: 4.01s
# 691:	learn: 380420.0528468	total: 8.98s	remaining: 4s
# 692:	learn: 380367.7197353	total: 9s	remaining: 3.98s
# 693:	learn: 376302.6452020	total: 9.01s	remaining: 3.97s
# 694:	learn: 375831.8792452	total: 9.03s	remaining: 3.96s
# 695:	learn: 375782.4159601	total: 9.04s	remaining: 3.95s
# 696:	learn: 375740.8523991	total: 9.05s	remaining: 3.93s
# 697:	learn: 375136.9331047	total: 9.06s	remaining: 3.92s
# 698:	learn: 375065.3351409	total: 9.08s	remaining: 3.91s
# 699:	learn: 374428.4472125	total: 9.09s	remaining: 3.9s
# 700:	learn: 374357.6641127	total: 9.11s	remaining: 3.88s
# 701:	learn: 374271.4564785	total: 9.12s	remaining: 3.87s
# 702:	learn: 373923.5465016	total: 9.13s	remaining: 3.86s
# 703:	learn: 373890.3440929	total: 9.15s	remaining: 3.85s
# 704:	learn: 373812.2002139	total: 9.16s	remaining: 3.83s
# 705:	learn: 373783.0323387	total: 9.17s	remaining: 3.82s
# 706:	learn: 373715.6050002	total: 9.19s	remaining: 3.81s
# 707:	learn: 373674.2332428	total: 9.2s	remaining: 3.79s
# 708:	learn: 373230.2765356	total: 9.21s	remaining: 3.78s
# 709:	learn: 373207.5287246	total: 9.22s	remaining: 3.77s
# 710:	learn: 373130.6030538	total: 9.24s	remaining: 3.75s
# 711:	learn: 372519.9219436	total: 9.25s	remaining: 3.74s
# 712:	learn: 372511.9004742	total: 9.26s	remaining: 3.73s
# 713:	learn: 372483.4384275	total: 9.28s	remaining: 3.71s
# 714:	learn: 372200.6722923	total: 9.29s	remaining: 3.7s
# 715:	learn: 372119.8493052	total: 9.3s	remaining: 3.69s
# 716:	learn: 372065.5015537	total: 9.32s	remaining: 3.68s
# 717:	learn: 368877.9325037	total: 9.33s	remaining: 3.67s
# 718:	learn: 364998.0072898	total: 9.35s	remaining: 3.65s
# 719:	learn: 364712.4239795	total: 9.36s	remaining: 3.64s
# 720:	learn: 364669.6461371	total: 9.37s	remaining: 3.63s
# 721:	learn: 364643.8478043	total: 9.38s	remaining: 3.61s
# 722:	learn: 361586.7445040	total: 9.4s	remaining: 3.6s
# 723:	learn: 361558.0658066	total: 9.41s	remaining: 3.59s
# 724:	learn: 361503.1340946	total: 9.42s	remaining: 3.57s
# 725:	learn: 361465.8931301	total: 9.44s	remaining: 3.56s
# 726:	learn: 361286.4677081	total: 9.45s	remaining: 3.55s
# 727:	learn: 361255.9639788	total: 9.46s	remaining: 3.54s
# 728:	learn: 361011.1496991	total: 9.48s	remaining: 3.52s
# 729:	learn: 360985.4369972	total: 9.49s	remaining: 3.51s
# 730:	learn: 359097.1772450	total: 9.51s	remaining: 3.5s
# 731:	learn: 359030.7268084	total: 9.52s	remaining: 3.48s
# 732:	learn: 356089.5342586	total: 9.53s	remaining: 3.47s
# 733:	learn: 356011.2063717	total: 9.55s	remaining: 3.46s
# 734:	learn: 354301.3482286	total: 9.56s	remaining: 3.45s
# 735:	learn: 354162.8887570	total: 9.57s	remaining: 3.43s
# 736:	learn: 351370.5385676	total: 9.59s	remaining: 3.42s
# 737:	learn: 351061.0663946	total: 9.6s	remaining: 3.41s
# 738:	learn: 351028.1114921	total: 9.62s	remaining: 3.4s
# 739:	learn: 350199.6524497	total: 9.63s	remaining: 3.38s
# 740:	learn: 346731.7069957	total: 9.64s	remaining: 3.37s
# 741:	learn: 346702.8909367	total: 9.66s	remaining: 3.36s
# 742:	learn: 346658.1047477	total: 9.67s	remaining: 3.34s
# 743:	learn: 346315.3612783	total: 9.69s	remaining: 3.33s
# 744:	learn: 346270.5283672	total: 9.7s	remaining: 3.32s
# 745:	learn: 346168.2117772	total: 9.71s	remaining: 3.31s
# 746:	learn: 346143.5104471	total: 9.72s	remaining: 3.29s
# 747:	learn: 346029.5923415	total: 9.74s	remaining: 3.28s
# 748:	learn: 344860.3127958	total: 9.75s	remaining: 3.27s
# 749:	learn: 344805.2615326	total: 9.77s	remaining: 3.25s
# 750:	learn: 344787.7684616	total: 9.78s	remaining: 3.24s
# 751:	learn: 344769.5117535	total: 9.79s	remaining: 3.23s
# 752:	learn: 344699.1698675	total: 9.8s	remaining: 3.21s
# 753:	learn: 344613.4128872	total: 9.82s	remaining: 3.2s
# 754:	learn: 344594.8815073	total: 9.83s	remaining: 3.19s
# 755:	learn: 344581.8981428	total: 9.84s	remaining: 3.18s
# 756:	learn: 344552.2447603	total: 9.86s	remaining: 3.16s
# 757:	learn: 344369.6980106	total: 9.87s	remaining: 3.15s
# 758:	learn: 344339.7456242	total: 9.89s	remaining: 3.14s
# 759:	learn: 344251.4239863	total: 9.9s	remaining: 3.13s
# 760:	learn: 344052.9210501	total: 9.91s	remaining: 3.11s
# 761:	learn: 344030.4076837	total: 9.93s	remaining: 3.1s
# 762:	learn: 344028.1506689	total: 9.94s	remaining: 3.09s
# 763:	learn: 343990.3292519	total: 9.95s	remaining: 3.07s
# 764:	learn: 340754.1234763	total: 9.97s	remaining: 3.06s
# 765:	learn: 340304.6566767	total: 9.98s	remaining: 3.05s
# 766:	learn: 340137.7603360	total: 9.99s	remaining: 3.04s
# 767:	learn: 336760.3417287	total: 10s	remaining: 3.02s
# 768:	learn: 336722.8890672	total: 10s	remaining: 3.01s
# 769:	learn: 336428.6992529	total: 10s	remaining: 3s
# 770:	learn: 336351.4453902	total: 10s	remaining: 2.98s
# 771:	learn: 336281.8086147	total: 10.1s	remaining: 2.97s
# 772:	learn: 336251.1893136	total: 10.1s	remaining: 2.96s
# 773:	learn: 336213.4927045	total: 10.1s	remaining: 2.94s
# 774:	learn: 334623.3956085	total: 10.1s	remaining: 2.93s
# 775:	learn: 334294.4329326	total: 10.1s	remaining: 2.92s
# 776:	learn: 334230.1869460	total: 10.1s	remaining: 2.91s
# 777:	learn: 334184.0687344	total: 10.1s	remaining: 2.89s
# 778:	learn: 334152.7961943	total: 10.2s	remaining: 2.88s
# 779:	learn: 334113.7333518	total: 10.2s	remaining: 2.87s
# 780:	learn: 334107.8026578	total: 10.2s	remaining: 2.85s
# 781:	learn: 334068.9835489	total: 10.2s	remaining: 2.84s
# 782:	learn: 334013.8321818	total: 10.2s	remaining: 2.83s
# 783:	learn: 333938.7727071	total: 10.2s	remaining: 2.81s
# 784:	learn: 333890.6105769	total: 10.2s	remaining: 2.8s
# 785:	learn: 330876.4492780	total: 10.2s	remaining: 2.79s
# 786:	learn: 330803.0103172	total: 10.3s	remaining: 2.78s
# 787:	learn: 330749.9236440	total: 10.3s	remaining: 2.76s
# 788:	learn: 330635.6114180	total: 10.3s	remaining: 2.75s
# 789:	learn: 330624.2532539	total: 10.3s	remaining: 2.74s
# 790:	learn: 330529.3849670	total: 10.3s	remaining: 2.72s
# 791:	learn: 330461.8542995	total: 10.3s	remaining: 2.71s
# 792:	learn: 330363.9809642	total: 10.3s	remaining: 2.7s
# 793:	learn: 330330.8345489	total: 10.3s	remaining: 2.68s
# 794:	learn: 330032.2968404	total: 10.4s	remaining: 2.67s
# 795:	learn: 329989.3053174	total: 10.4s	remaining: 2.66s
# 796:	learn: 329985.7080551	total: 10.4s	remaining: 2.65s
# 797:	learn: 329877.0207752	total: 10.4s	remaining: 2.63s
# 798:	learn: 329847.3279571	total: 10.4s	remaining: 2.62s
# 799:	learn: 329814.7068181	total: 10.4s	remaining: 2.61s
# 800:	learn: 329752.7026069	total: 10.4s	remaining: 2.59s
# 801:	learn: 329714.8943362	total: 10.5s	remaining: 2.58s
# 802:	learn: 329548.8104364	total: 10.5s	remaining: 2.57s
# 803:	learn: 329248.3298821	total: 10.5s	remaining: 2.56s
# 804:	learn: 329224.1728089	total: 10.5s	remaining: 2.54s
# 805:	learn: 329178.9450128	total: 10.5s	remaining: 2.53s
# 806:	learn: 329070.6224911	total: 10.5s	remaining: 2.52s
# 807:	learn: 329064.7768554	total: 10.5s	remaining: 2.5s
# 808:	learn: 328958.3590781	total: 10.5s	remaining: 2.49s
# 809:	learn: 328896.0924823	total: 10.6s	remaining: 2.48s
# 810:	learn: 328891.2960474	total: 10.6s	remaining: 2.46s
# 811:	learn: 328863.2397226	total: 10.6s	remaining: 2.45s
# 812:	learn: 328764.3222787	total: 10.6s	remaining: 2.44s
# 813:	learn: 328745.4573680	total: 10.6s	remaining: 2.42s
# 814:	learn: 328692.8260704	total: 10.6s	remaining: 2.41s
# 815:	learn: 328639.3733530	total: 10.6s	remaining: 2.4s
# 816:	learn: 328570.8789389	total: 10.6s	remaining: 2.38s
# 817:	learn: 328538.6731003	total: 10.7s	remaining: 2.37s
# 818:	learn: 328456.4332399	total: 10.7s	remaining: 2.36s
# 819:	learn: 328433.5646724	total: 10.7s	remaining: 2.35s
# 820:	learn: 328363.2304531	total: 10.7s	remaining: 2.33s
# 821:	learn: 328343.9157729	total: 10.7s	remaining: 2.32s
# 822:	learn: 325316.5968809	total: 10.7s	remaining: 2.31s
# 823:	learn: 325282.2601523	total: 10.7s	remaining: 2.29s
# 824:	learn: 325238.3150878	total: 10.8s	remaining: 2.28s
# 825:	learn: 324948.4518191	total: 10.8s	remaining: 2.27s
# 826:	learn: 324944.8219569	total: 10.8s	remaining: 2.25s
# 827:	learn: 324926.1348344	total: 10.8s	remaining: 2.24s
# 828:	learn: 324907.5151996	total: 10.8s	remaining: 2.23s
# 829:	learn: 324275.0343575	total: 10.8s	remaining: 2.21s
# 830:	learn: 324246.6331991	total: 10.8s	remaining: 2.2s
# 831:	learn: 324212.1694629	total: 10.8s	remaining: 2.19s
# 832:	learn: 324198.0894155	total: 10.9s	remaining: 2.18s
# 833:	learn: 324161.1198699	total: 10.9s	remaining: 2.16s
# 834:	learn: 324111.7567439	total: 10.9s	remaining: 2.15s
# 835:	learn: 324062.2703732	total: 10.9s	remaining: 2.14s
# 836:	learn: 324023.8525811	total: 10.9s	remaining: 2.13s
# 837:	learn: 324017.8703278	total: 10.9s	remaining: 2.11s
# 838:	learn: 323981.7442027	total: 10.9s	remaining: 2.1s
# 839:	learn: 323947.0378512	total: 11s	remaining: 2.09s
# 840:	learn: 323919.3170720	total: 11s	remaining: 2.07s
# 841:	learn: 323889.9046392	total: 11s	remaining: 2.06s
# 842:	learn: 323884.7329132	total: 11s	remaining: 2.05s
# 843:	learn: 323696.8311345	total: 11s	remaining: 2.03s
# 844:	learn: 323442.7567942	total: 11s	remaining: 2.02s
# 845:	learn: 323288.2796863	total: 11s	remaining: 2.01s
# 846:	learn: 323231.5817736	total: 11s	remaining: 2s
# 847:	learn: 323189.7924374	total: 11.1s	remaining: 1.98s
# 848:	learn: 323153.0772770	total: 11.1s	remaining: 1.97s
# 849:	learn: 323097.5713709	total: 11.1s	remaining: 1.96s
# 850:	learn: 321696.0075993	total: 11.1s	remaining: 1.94s
# 851:	learn: 321666.3263759	total: 11.1s	remaining: 1.93s
# 852:	learn: 321656.0814270	total: 11.1s	remaining: 1.92s
# 853:	learn: 320980.2395254	total: 11.1s	remaining: 1.9s
# 854:	learn: 320714.7992465	total: 11.2s	remaining: 1.89s
# 855:	learn: 320689.1741467	total: 11.2s	remaining: 1.88s
# 856:	learn: 320630.7173215	total: 11.2s	remaining: 1.86s
# 857:	learn: 320384.8347102	total: 11.2s	remaining: 1.85s
# 858:	learn: 320317.3768770	total: 11.2s	remaining: 1.84s
# 859:	learn: 320148.0540222	total: 11.2s	remaining: 1.83s
# 860:	learn: 320075.0588211	total: 11.2s	remaining: 1.81s
# 861:	learn: 319941.4986145	total: 11.2s	remaining: 1.8s
# 862:	learn: 319893.0277018	total: 11.3s	remaining: 1.79s
# 863:	learn: 319872.3477068	total: 11.3s	remaining: 1.77s
# 864:	learn: 319828.2850711	total: 11.3s	remaining: 1.76s
# 865:	learn: 319745.5951406	total: 11.3s	remaining: 1.75s
# 866:	learn: 319723.8221488	total: 11.3s	remaining: 1.74s
# 867:	learn: 319722.9661573	total: 11.3s	remaining: 1.72s
# 868:	learn: 319721.8783734	total: 11.3s	remaining: 1.71s
# 869:	learn: 319433.5007772	total: 11.3s	remaining: 1.7s
# 870:	learn: 319189.7621632	total: 11.4s	remaining: 1.68s
# 871:	learn: 319098.0522864	total: 11.4s	remaining: 1.67s
# 872:	learn: 319065.1774518	total: 11.4s	remaining: 1.66s
# 873:	learn: 319021.7938485	total: 11.4s	remaining: 1.64s
# 874:	learn: 318990.7087241	total: 11.4s	remaining: 1.63s
# 875:	learn: 318987.6241422	total: 11.4s	remaining: 1.62s
# 876:	learn: 318915.1712340	total: 11.4s	remaining: 1.6s
# 877:	learn: 318804.2170493	total: 11.5s	remaining: 1.59s
# 878:	learn: 318799.4696517	total: 11.5s	remaining: 1.58s
# 879:	learn: 318240.3172430	total: 11.5s	remaining: 1.56s
# 880:	learn: 318237.0137079	total: 11.5s	remaining: 1.55s
# 881:	learn: 318140.1757068	total: 11.5s	remaining: 1.54s
# 882:	learn: 317971.3805846	total: 11.5s	remaining: 1.52s
# 883:	learn: 317948.8069919	total: 11.5s	remaining: 1.51s
# 884:	learn: 317917.2342048	total: 11.5s	remaining: 1.5s
# 885:	learn: 317895.5796881	total: 11.6s	remaining: 1.49s
# 886:	learn: 317781.6258180	total: 11.6s	remaining: 1.47s
# 887:	learn: 317748.9669417	total: 11.6s	remaining: 1.46s
# 888:	learn: 317728.3734870	total: 11.6s	remaining: 1.45s
# 889:	learn: 317725.0837389	total: 11.6s	remaining: 1.43s
# 890:	learn: 317685.2528433	total: 11.6s	remaining: 1.42s
# 891:	learn: 317492.5444441	total: 11.6s	remaining: 1.41s
# 892:	learn: 316742.8974358	total: 11.6s	remaining: 1.4s
# 893:	learn: 316648.5904252	total: 11.7s	remaining: 1.38s
# 894:	learn: 316491.9854075	total: 11.7s	remaining: 1.37s
# 895:	learn: 313875.9812349	total: 11.7s	remaining: 1.36s
# 896:	learn: 313767.2894527	total: 11.7s	remaining: 1.34s
# 897:	learn: 313643.6639259	total: 11.7s	remaining: 1.33s
# 898:	learn: 313589.8380977	total: 11.7s	remaining: 1.32s
# 899:	learn: 313555.3074937	total: 11.7s	remaining: 1.3s
# 900:	learn: 313324.8333954	total: 11.8s	remaining: 1.29s
# 901:	learn: 313291.5391802	total: 11.8s	remaining: 1.28s
# 902:	learn: 313028.2750496	total: 11.8s	remaining: 1.26s
# 903:	learn: 313025.2409748	total: 11.8s	remaining: 1.25s
# 904:	learn: 313003.0061425	total: 11.8s	remaining: 1.24s
# 905:	learn: 312972.8057323	total: 11.8s	remaining: 1.23s
# 906:	learn: 312947.0098227	total: 11.8s	remaining: 1.21s
# 907:	learn: 312931.0456142	total: 11.8s	remaining: 1.2s
# 908:	learn: 312896.2488078	total: 11.9s	remaining: 1.19s
# 909:	learn: 312819.6988980	total: 11.9s	remaining: 1.17s
# 910:	learn: 312743.7310631	total: 11.9s	remaining: 1.16s
# 911:	learn: 312708.5278689	total: 11.9s	remaining: 1.15s
# 912:	learn: 312666.2029912	total: 11.9s	remaining: 1.14s
# 913:	learn: 312611.1666180	total: 11.9s	remaining: 1.12s
# 914:	learn: 312361.9244389	total: 11.9s	remaining: 1.11s
# 915:	learn: 312286.9967659	total: 12s	remaining: 1.1s
# 916:	learn: 312268.2846699	total: 12s	remaining: 1.08s
# 917:	learn: 312172.0964012	total: 12s	remaining: 1.07s
# 918:	learn: 312165.5704477	total: 12s	remaining: 1.06s
# 919:	learn: 312131.4764814	total: 12s	remaining: 1.04s
# 920:	learn: 312028.7949710	total: 12s	remaining: 1.03s
# 921:	learn: 311944.0687721	total: 12s	remaining: 1.02s
# 922:	learn: 311922.5792540	total: 12s	remaining: 1s
# 923:	learn: 311913.4838278	total: 12.1s	remaining: 992ms
# 924:	learn: 311884.0469117	total: 12.1s	remaining: 979ms
# 925:	learn: 309195.6754050	total: 12.1s	remaining: 966ms
# 926:	learn: 309120.2890513	total: 12.1s	remaining: 953ms
# 927:	learn: 308954.2501498	total: 12.1s	remaining: 940ms
# 928:	learn: 308863.9472082	total: 12.1s	remaining: 927ms
# 929:	learn: 308839.7286501	total: 12.1s	remaining: 914ms
# 930:	learn: 306349.5767006	total: 12.2s	remaining: 901ms
# 931:	learn: 306348.3594574	total: 12.2s	remaining: 888ms
# 932:	learn: 306312.9068356	total: 12.2s	remaining: 875ms
# 933:	learn: 306225.0688094	total: 12.2s	remaining: 862ms
# 934:	learn: 306188.1415096	total: 12.2s	remaining: 849ms
# 935:	learn: 306169.2633389	total: 12.2s	remaining: 836ms
# 936:	learn: 306066.1692343	total: 12.2s	remaining: 823ms
# 937:	learn: 306061.0634511	total: 12.2s	remaining: 809ms
# 938:	learn: 305497.6505175	total: 12.3s	remaining: 796ms
# 939:	learn: 305495.9250562	total: 12.3s	remaining: 783ms
# 940:	learn: 305411.5310357	total: 12.3s	remaining: 770ms
# 941:	learn: 303023.8764936	total: 12.3s	remaining: 757ms
# 942:	learn: 302974.6357761	total: 12.3s	remaining: 744ms
# 943:	learn: 302901.5040841	total: 12.3s	remaining: 731ms
# 944:	learn: 302801.7365075	total: 12.3s	remaining: 718ms
# 945:	learn: 302767.6363181	total: 12.3s	remaining: 705ms
# 946:	learn: 302711.9110664	total: 12.4s	remaining: 692ms
# 947:	learn: 302596.8837956	total: 12.4s	remaining: 679ms
# 948:	learn: 302571.9521765	total: 12.4s	remaining: 666ms
# 949:	learn: 302541.0126579	total: 12.4s	remaining: 653ms
# 950:	learn: 302513.9292361	total: 12.4s	remaining: 640ms
# 951:	learn: 302464.7633496	total: 12.4s	remaining: 627ms
# 952:	learn: 302460.0064602	total: 12.4s	remaining: 614ms
# 953:	learn: 302445.4418107	total: 12.5s	remaining: 600ms
# 954:	learn: 302389.7103047	total: 12.5s	remaining: 587ms
# 955:	learn: 302352.3972621	total: 12.5s	remaining: 574ms
# 956:	learn: 302351.2384963	total: 12.5s	remaining: 561ms
# 957:	learn: 302334.0600866	total: 12.5s	remaining: 548ms
# 958:	learn: 302310.2429926	total: 12.5s	remaining: 535ms
# 959:	learn: 302200.3554619	total: 12.5s	remaining: 522ms
# 960:	learn: 302170.2720993	total: 12.5s	remaining: 509ms
# 961:	learn: 302169.3058950	total: 12.6s	remaining: 496ms
# 962:	learn: 302151.2378861	total: 12.6s	remaining: 483ms
# 963:	learn: 302111.4615113	total: 12.6s	remaining: 470ms
# 964:	learn: 301854.4424746	total: 12.6s	remaining: 457ms
# 965:	learn: 301818.3808081	total: 12.6s	remaining: 444ms
# 966:	learn: 301817.4018827	total: 12.6s	remaining: 431ms
# 967:	learn: 301816.3352452	total: 12.6s	remaining: 418ms
# 968:	learn: 301799.6780875	total: 12.6s	remaining: 404ms
# 969:	learn: 301764.6754857	total: 12.7s	remaining: 391ms
# 970:	learn: 301763.7826821	total: 12.7s	remaining: 378ms
# 971:	learn: 301762.8100053	total: 12.7s	remaining: 365ms
# 972:	learn: 301666.6904674	total: 12.7s	remaining: 352ms
# 973:	learn: 301665.7327597	total: 12.7s	remaining: 339ms
# 974:	learn: 301605.5043118	total: 12.7s	remaining: 326ms
# 975:	learn: 301604.6013726	total: 12.7s	remaining: 313ms
# 976:	learn: 301587.4552954	total: 12.7s	remaining: 300ms
# 977:	learn: 298038.6475452	total: 12.8s	remaining: 287ms
# 978:	learn: 297974.8486539	total: 12.8s	remaining: 274ms
# 979:	learn: 297821.2372785	total: 12.8s	remaining: 261ms
# 980:	learn: 297807.7580529	total: 12.8s	remaining: 248ms
# 981:	learn: 297748.0891792	total: 12.8s	remaining: 235ms
# 982:	learn: 297719.5771843	total: 12.8s	remaining: 222ms
# 983:	learn: 297718.7655438	total: 12.8s	remaining: 209ms
# 984:	learn: 297672.7795627	total: 12.8s	remaining: 196ms
# 985:	learn: 297630.9019283	total: 12.9s	remaining: 183ms
# 986:	learn: 297611.7793954	total: 12.9s	remaining: 170ms
# 987:	learn: 297404.4504410	total: 12.9s	remaining: 157ms
# 988:	learn: 296236.3960079	total: 12.9s	remaining: 144ms
# 989:	learn: 296213.1295043	total: 12.9s	remaining: 131ms
# 990:	learn: 296154.7195014	total: 12.9s	remaining: 117ms
# 991:	learn: 296121.0378961	total: 13s	remaining: 104ms
# 992:	learn: 296037.8852275	total: 13s	remaining: 91.4ms
# 993:	learn: 296001.8005850	total: 13s	remaining: 78.4ms
# 994:	learn: 295974.9586096	total: 13s	remaining: 65.3ms
# 995:	learn: 295931.8160374	total: 13s	remaining: 52.3ms
# 996:	learn: 294794.9983698	total: 13s	remaining: 39.2ms
# 997:	learn: 294787.0552452	total: 13s	remaining: 26.1ms
# 998:	learn: 294765.5090903	total: 13.1s	remaining: 13.1ms
# 999:	learn: 294753.3322168	total: 13.1s	remaining: 0us
# Wall time: 7min 35s

# %%
scoresheet2
# Out:
#      train_score  test_score
# lr     35.474589   35.506236
# ls     35.469078   35.437952
# rg     35.679770   35.545026
# el     39.071232   39.840766
# dt      0.000000   16.657764
# et      0.005530   12.639187
# rf      6.666635   13.459264
# ab     37.362337   69.169891
# gb     21.678850   21.517479
# hgb    20.183958   19.143066
# xg     10.592622   27.751573
# lg     19.865698   21.975384
# cat    12.242266   30.405833

# %% [markdown]
# **REPORT:**
# - Combination of SuperVectorizer and RandomForest performs the best (12.6)
# - Addition of Robust Scaler lowers it to (13.7)
# - Using TableVectorizer instead also lowers it to (13.4) without Robust Scaler

# %% [markdown]
# **REPORT:**
# - After applying some hyperparameters these are the better performing models:
#     - CatBoostRegressor
#     - HistGradientBoostingRegressor
#     - ExtraTreesRegressor
#     - RandomForestRegressor

# %% [markdown]
# ### Train-test-valid split for cross validation and Hyperparmater optimization

# %%
X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, train_size = 0.5, random_state = 42)

# %%
sv_X_valid = sv.transform(X_valid)
tv_X_valid = tv.transform(X_valid)

# %%
def maepercent(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    return mae * 100 / y_true.mean()

# %%
cat_params = {'iterations': 264,
 'learning_rate': 0.15322245695737738,
 'depth': 9,
 'l2_leaf_reg': 5.562675266419676,
 'early_stopping_rounds': 14}

hgb_params = {'max_iter': 333,
 'learning_rate': 0.15393558857357315,
 'max_depth': 9,
 'l2_regularization': 0.8655633274690765,
 'min_samples_leaf': 17}
# Out:
# {'iterations': 264,
#  'learning_rate': 0.15322245695737738,
#  'depth': 9,
#  'l2_leaf_reg': 5.562675266419676,
#  'early_stopping_rounds': 14}

# %%
best_hyperparams#hgb
# Out:
# {'max_iter': 333,
#  'learning_rate': 0.15393558857357315,
#  'max_depth': 9,
#  'l2_leaf_reg': 0.8655633274690765,
#  'min_samples_leaf': 17}

# %%
def objective(trial):
    model= ExtraTreesRegressor(
        n_estimators = trial.suggest_int('n_estimators', 100, 1500),
        max_depth = trial.suggest_int('max_depth', 1, 15), # depth above 10 usually introduces overfitting
        min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20),
        min_samples_split = trial.suggest_int('min_samples_split', 1, 20),
        max_features = trial.suggest_categorical('max_features', ['auto', 'log2', 'sqrt']),
        criterion = 'absolute_error'
    )

    
    model.fit(sv_X_train, y_train)

    return maepercent(y_valid, model.predict(sv_X_valid))

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

best_hyperparams = study.best_params
# Out:
# [I 2023-08-19 16:37:58,286] A new study created in memory with name: no-name-5f2fe01b-cef4-4c84-9375-9c7d6b9cbf69

# %%
best_hyperparams

# %% [markdown]
# ### Dirty implementation

# %%
ntrain = train[num_cols]
ntest = test[num_cols]

# %%
nX_train = ntrain.drop('listed_price', axis = 1)
ny_train = ntrain['listed_price']
nX_test = ntest.drop(['listed_price'], axis = 1)
ny_test = ntest['listed_price']

# %%
lr = RandomForestRegressor()
lr.fit(nX_train, ny_train)
preds = lr.predict(nX_test)

# %%
mae = mean_absolute_error(ny_test, preds)
mae_percent = mae * 100/ ny_test.mean()

# %%
print('MAE: ', mae)
print('MAE percent: ', mae_percent)
# Out:
# MAE:  102584.15517648886
# MAE percent:  12.971815950151319
